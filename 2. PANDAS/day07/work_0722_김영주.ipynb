# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic=pd.read_csv(r'C:\Users\desktop\EX_PANDAS 06\data\titanic.csv')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
data=titanic[['survived','sex','age']]
data
# Out:
#      survived     sex   age
# 0           0    male  22.0
# 1           1  female  38.0
# 2           1  female  26.0
# 3           1  female  35.0
# 4           0    male  35.0
# ..        ...     ...   ...
# 886         0    male  27.0
# 887         1  female  19.0
# 888         0  female   NaN
# 889         1    male  26.0
# 890         0    male  32.0
#
# [891 rows x 3 columns]

# %%
data.isna().sum()
# Out:
# survived      0
# sex           0
# age         177
# dtype: int64

# %%
data['survived'].replace(0,np.nan,inplace=True)
# Out:
# C:\Users\desktop\AppData\Local\Temp\ipykernel_22096\2229553616.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['survived'].replace(0,np.nan,inplace=True)
# C:\Users\desktop\AppData\Local\Temp\ipykernel_22096\2229553616.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['survived'].replace(0,np.nan,inplace=True)

# %%
data.isna().sum()
# Out:
# survived    549
# sex           0
# age         177
# dtype: int64

# %%
data2=data.dropna().copy()
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 290 entries, 1 to 889
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  290 non-null    float64
#  1   sex       290 non-null    object
#  2   age       290 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 9.1+ KB

# %%
data2.isna().sum()
# Out:
# survived    0
# sex         0
# age         0
# dtype: int64

# %%
data2=data2.set_index('sex')
data2
# Out:
#         survived   age
# sex
# female       1.0  38.0
# female       1.0  26.0
# female       1.0  35.0
# female       1.0  27.0
# female       1.0  14.0
# ...          ...   ...
# female       1.0  15.0
# female       1.0  56.0
# female       1.0  25.0
# female       1.0  19.0
# male         1.0  26.0
#
# [290 rows x 2 columns]

# %%
df_f=data2.loc['female',:]
df_m=data2.loc['male',:]

# %%
df_f['age_range']=df_f['age']//10
df_f
# Out:
#         survived   age  age_range
# sex
# female       1.0  38.0        3.0
# female       1.0  26.0        2.0
# female       1.0  35.0        3.0
# female       1.0  27.0        2.0
# female       1.0  14.0        1.0
# ...          ...   ...        ...
# female       1.0  28.0        2.0
# female       1.0  15.0        1.0
# female       1.0  56.0        5.0
# female       1.0  25.0        2.0
# female       1.0  19.0        1.0
#
# [197 rows x 3 columns]

# %%
df_m['age_range']=df_m['age']//10
df_m
# Out:
#       survived    age  age_range
# sex
# male       1.0  34.00        3.0
# male       1.0  28.00        2.0
# male       1.0  32.00        3.0
# male       1.0   0.83        0.0
# male       1.0  29.00        2.0
# ...        ...    ...        ...
# male       1.0   0.83        0.0
# male       1.0  32.00        3.0
# male       1.0  51.00        5.0
# male       1.0   4.00        0.0
# male       1.0  26.00        2.0
#
# [93 rows x 3 columns]

# %%
f_age=df_f.value_counts('age_range')
f_age=sorted(f_age.items())
f_age
# Out:
# [(0.0, 19), (1.0, 34), (2.0, 52), (3.0, 50), (4.0, 22), (5.0, 16), (6.0, 4)]

# %%
m_age=df_m.value_counts('age_range')
m_age=sorted(m_age.items())
m_age
# Out:
# [(0.0, 19),
#  (1.0, 7),
#  (2.0, 25),
#  (3.0, 23),
#  (4.0, 12),
#  (5.0, 4),
#  (6.0, 2),
#  (8.0, 1)]

# %%
f_df=pd.DataFrame(f_age,columns=['x','y'])
m_df=pd.DataFrame(m_age,columns=['x','y'])

# %%
df = pd.merge(f_df, m_df, on='x')
df.set_index('x')
# Out:
#      y_x  y_y
# x
# 0.0   19   19
# 1.0   34    7
# 2.0   52   25
# 3.0   50   23
# 4.0   22   12
# 5.0   16    4
# 6.0    4    2

# %%
plt.plot(df['y_x'],label='female')
plt.plot(df['y_y'],label='male')
plt.legend()
plt.show()
