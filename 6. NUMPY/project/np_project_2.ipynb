# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score

# %%
ins=pd.read_csv('insurance.csv')
ins
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
ins.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
plt.scatter(ins['age'],ins['charges'],color='#74AEDB')
plt.xlabel('age')
plt.ylabel('charges')
plt.show()

# %%
x1=ins[ins['charges']<=15000]['age'].to_list()
y1=ins[ins['charges']<=15000]['charges'].to_list()

b1,b2=np.polyfit(x1,y1,1)

plt.scatter(ins[ins['charges']<=15000]['age'],ins[ins['charges']<=15000]['charges'],color='#74AEDB')
plt.plot(x1,np.array(x1)*b1+b2,color='red',label='y1={:.2f}x1 +{:.2f}'.format(b1,b2))
plt.xlabel('age')
plt.ylabel('charges')
plt.legend()
plt.show()

# %%
est=np.array(x1)*b1+b2
r2=r2_score(y1,est)
print(r2)
# Out:
# 0.8033493556373386

# %%
x1=ins[ins['charges']<=15000]['age'].to_list()
y1=ins[ins['charges']<=15000]['charges'].to_list()

b1,b2=np.polyfit(x1,y1,1)

plt.scatter(ins[ins['charges']<=15000]['age'],ins[ins['charges']<=15000]['charges'],color='#74AEDB')
plt.plot(x1,np.array(x1)*b1+b2,color='red')
plt.text(50, 5000, '$R^2$ = %.4f'%r2, size = 12)
plt.xlabel('age')
plt.ylabel('charges')
plt.show()

# %%
x2 = ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['age'].to_list()
y2 = ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['charges'].to_list()


b1,b2=np.polyfit(x2,y2,1)

plt.scatter(ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['age'],
            ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['charges'],color='#74AEDB')
plt.plot(x2,np.array(x2)*b1+b2,color='red',label='y2={:.2f}x2+{:.2f}'.format(b1,b2))
plt.xlabel('age')
plt.ylabel('charges')
plt.show()

# %%
est=np.array(x2)*b1+b2
r2=r2_score(y2,est)
print(r2)
# Out:
# 0.2405778535575318

# %%
x2 = ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['age'].to_list()
y2 = ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['charges'].to_list()

b1,b2=np.polyfit(x2,y2,1)

plt.scatter(ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['age'],
            ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['charges'],color='#74AEDB')
plt.plot(x2,np.array(x2)*b1+b2,color='red',label='y2={:.2f}x2+{:.2f}'.format(b1,b2))
plt.text(50, 18000, '$R^2$ = %.4f'%r2, size = 12)
plt.xlabel('age')
plt.ylabel('charges')
plt.show()

# %%
x3 = ins[(ins['charges'] > 30000)]['age'].to_list()
y3 = ins[(ins['charges'] > 30000)]['charges'].to_list()


b1,b2=np.polyfit(x3,y3,1)

plt.scatter(ins[(ins['charges'] > 30000)]['age'], ins[(ins['charges'] > 30000)]['charges'])
plt.plot(x3,np.array(x3)*b1+b2,color='red',label='y3={:.2f}x3+{:.2f}'.format(b1,b2))
plt.xlabel('age')
plt.ylabel('charges')
plt.legend()
plt.show()

# %%
est=np.array(x3)*b1+b2
r2=r2_score(y3,est)
print(r2)
# Out:
# 0.2124092260515631

# %%
x3 = ins[(ins['charges'] > 30000)]['age'].to_list()
y3 = ins[(ins['charges'] > 30000)]['charges'].to_list()


b1,b2=np.polyfit(x3,y3,1)

plt.scatter(ins[(ins['charges'] > 30000)]['age'], ins[(ins['charges'] > 30000)]['charges'],color='#74AEDB')
plt.plot(x3,np.array(x3)*b1+b2,color='red',label='y3={:.2f}x3+{:.2f}'.format(b1,b2))

plt.text(40, 55000, '$R^2$ = %.4f'%r2, size = 12)
plt.xlabel('age')
plt.ylabel('charges')
plt.show()

# %%
plt.scatter(ins['bmi'],ins['charges'],color='#74AEDB')
plt.xlabel('bmi')
plt.ylabel('charges')
plt.show()

# %%
x6=ins[ins['charges']<=15000]['bmi'].to_list()
y6=ins[ins['charges']<=15000]['charges'].to_list()

b1,b2=np.polyfit(x6,y6,1)

plt.scatter(ins[ins['charges']<=15000]['bmi'],ins[ins['charges']<=15000]['charges'])
plt.plot(x1,np.array(x1)*b1+b2,color='red',label='y1={:.2f}x1 +{:.2f}'.format(b1,b2))
plt.xlabel('bmi')
plt.ylabel('charges')
plt.legend()
plt.show()

# %%
est=np.array(x6)*b1+b2
r2=r2_score(y6,est)
print(r2)
# Out:
# 0.00536745927051252

# %%
x6=ins[ins['charges']<=15000]['bmi'].to_list()
y6=ins[ins['charges']<=15000]['charges'].to_list()

b1,b2=np.polyfit(x6,y6,1)

plt.scatter(ins[ins['charges']<=15000]['bmi'],ins[ins['charges']<=15000]['charges'],color='#74AEDB')
plt.plot(x1,np.array(x1)*b1+b2,color='red',label='y1={:.2f}x1 +{:.2f}'.format(b1,b2))

plt.text(50, 5000, '$R^2$ = %.4f'%r2, size = 12)
plt.xlabel('bmi')
plt.ylabel('charges')
plt.show()

# %%
x4 = ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['bmi'].to_list()
y4 = ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['charges'].to_list()


b1,b2=np.polyfit(x4,y4,1)

plt.scatter(ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['bmi'],
            ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['charges'])
plt.plot(x4,np.array(x4)*b1+b2,color='red',label='y4={:.2f}x4+{:.2f}'.format(b1,b2))
plt.xlabel('bmi')
plt.ylabel('charges')
plt.show()

# %%
est=np.array(x4)*b1+b2
r2=r2_score(y4,est)
print(r2)
# Out:
# 0.003728819546183537

# %%
x4 = ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['bmi'].to_list()
y4 = ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['charges'].to_list()


b1,b2=np.polyfit(x4,y4,1)

plt.scatter(ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['bmi'],
            ins[(15000 < ins['charges']) & (ins['charges'] <= 30000)]['charges'],color='#74AEDB')
plt.plot(x4,np.array(x4)*b1+b2,color='red',label='y4={:.2f}x4+{:.2f}'.format(b1,b2))


plt.text(35, 18000, '$R^2$ = %.4f'%r2, size = 12)
plt.xlabel('bmi')
plt.ylabel('charges')
plt.show()

# %%
x5 = ins[(ins['charges'] > 30000)]['bmi'].to_list()
y5 = ins[(ins['charges'] > 30000)]['charges'].to_list()


b1,b2=np.polyfit(x5,y5,1)

plt.scatter(ins[(ins['charges'] > 30000)]['bmi'], ins[(ins['charges'] > 30000)]['charges'])
plt.plot(x5,np.array(x5)*b1+b2,color='red',label='y5={:.2f}x5+{:.2f}'.format(b1,b2))
plt.xlabel('bmi')
plt.ylabel('charges')
plt.legend()
plt.show()

# %%
est=np.array(x5)*b1+b2
r2=r2_score(y5,est)
print(r2)
# Out:
# 0.20015443539335953

# %%
x5 = ins[(ins['charges'] > 30000)]['bmi'].to_list()
y5 = ins[(ins['charges'] > 30000)]['charges'].to_list()


b1,b2=np.polyfit(x5,y5,1)

plt.scatter(ins[(ins['charges'] > 30000)]['bmi'], ins[(ins['charges'] > 30000)]['charges'],color='#74AEDB')
plt.plot(x5,np.array(x5)*b1+b2,color='red',label='y5={:.2f}x5+{:.2f}'.format(b1,b2))

plt.text(22, 52500, '$R^2$ = %.4f'%r2, size = 12)
plt.xlabel('bmi')
plt.ylabel('charges')
plt.show()

# %%
colors = {'female': '#EDBAB9', 'male': '#74AEDB'}

for i in ins['sex'].unique():
    subset = ins[ins['sex'] == i]
    plt.scatter(subset['age'], subset['charges'],
                color=colors[i], label=i, alpha=0.7)

plt.xlabel("Age")
plt.ylabel("Charges")
plt.legend(title='sex', loc='upper left')
plt.show()

# %%
colors = {'yes': '#EDBAB9', 'no': '#74AEDB'}

for smoker_status in ins['smoker'].unique():
    subset = ins[ins['smoker'] == smoker_status]
    plt.scatter(subset['age'], subset['charges'],
                color=colors[smoker_status], label=smoker_status, alpha=0.7)

plt.xlabel("Age")
plt.ylabel("Charges")
plt.legend(title='Smoker', loc='upper left')
plt.show()
