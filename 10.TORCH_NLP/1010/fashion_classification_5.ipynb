# %%
## 모듈 로드
import pandas as pd
from konlpy.tag import Okt
from collections import Counter
import numpy as np
import torch
from torch.utils.data import TensorDataset, DataLoader
from torch import optim
from torch import nn

import os
import json
import re
import string

# %%
class reviewClassifierModel(nn.Module):
    def __init__(self, n_vocab, hidden_dim, embedding_dim, n_classes,
                 n_layers, dropout=0.5, bidirectional=True) -> None:
        super().__init__()
        self.embedding = nn.Embedding(
            num_embeddings=n_vocab,         # num_embeddings = vocab이 들어감
            embedding_dim=embedding_dim,
            padding_idx=0
        )
        self.model = nn.LSTM(
            input_size = embedding_dim,         # Input의 사이즈에 해당하는 수
            hidden_size=hidden_dim,             # 은닉층의 사이즈에 해당하는 수
            num_layers=n_layers,                # RNN의 은닉층 레이어 개수, default = 1
            bidirectional=bidirectional,        # bidrectional True일시 양방향 RNN, default = False
            dropout=dropout,                    # dropout 비율설정 기본값 0
            batch_first=True,                   # True일 경우 Output 사이즈는 (batch, seq, feature) 기본값 False
        )
        if bidirectional:
            self.classifier1 = nn.Linear(hidden_dim*2,n_classes)
            self.classifier2 = nn.Linear(hidden_dim*2,1)
        else:
            self.classifier1 = nn.Linear(hidden_dim,n_classes)
            self.classifier2 = nn.Linear(hidden_dim,1)
        self.dropout = nn.Dropout(dropout)

    def forward(self,inputs):
        embeddings = self.embedding(inputs)
        output, _ = self.model(embeddings)
        last_output = output[:, -1, :]
        last_output = self.dropout(last_output)
        classesd = self.classifier1(last_output)
        logits = self.classifier2(last_output)

        # LogSoftmax 적용
        classesd = nn.LogSoftmax(dim=1)(classesd)  # 다중 클래스 출력에 LogSoftmax 적용

        return classesd, logits

# %%
TRAIN_PATH = './DATA/Training/'
# 여러 폴더 경로를 리스트로 저장
folder_paths = os.listdir(TRAIN_PATH)

# 빈 데이터프레임 리스트 생성
dataframes = []

# 각 폴더 내의 JSON 파일을 읽어와 데이터프레임으로 변환
for folder_path in folder_paths:
    FOLDER_PATH = TRAIN_PATH+folder_path
    print(f"Processing folder: {folder_path}")
    
    # 폴더 내의 모든 JSON 파일 리스트
    json_files = [file for file in os.listdir(FOLDER_PATH) if file.endswith('.json')]

    for file in json_files:
        file_path = os.path.join(FOLDER_PATH, file)
        print(f"Loading file: {file_path}")
        
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
                
                # 파일 내용 확인 및 데이터프레임으로 변환
                if data:
                    # Aspects만 추출
                    for review in data:
                        aspects = pd.json_normalize(review.get('Aspects'))
                        dataframes.append(aspects)
                else:
                    print(f"No data found in {file}")
                    
        except json.JSONDecodeError:
            print(f"Error loading {file}: Invalid JSON")

# 데이터프레임 결합
if dataframes:
    final_dataframe = pd.concat(dataframes, ignore_index=True)
    print(final_dataframe)
else:
    print("No valid dataframes to concatenate.")
final_dataframe.to_csv('./DATA/train.csv')
# Out:
# Processing folder: TL_쇼핑몰_01.패션_1-1.여성의류
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(1).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(10).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(100).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(101).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(102).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(103).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(104).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(105).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(106).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(107).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(108).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(109).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(11).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(110).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(111).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(112).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(113).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(114).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(115).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(116).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(117).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(118).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(119).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(12).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(120).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(121).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(122).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(123).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(124).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(125).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(126).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(127).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(128).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(129).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(13).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(130).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(131).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(132).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(133).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(134).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(135).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(136).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(137).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(138).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(139).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(14).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(140).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(141).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(142).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(143).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(144).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(145).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(146).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(147).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(148).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(149).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(15).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(150).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(151).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(152).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(153).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(154).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(155).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(16).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(17).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(18).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(19).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(2).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(20).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(21).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(22).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(23).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(24).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(25).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(26).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(27).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(28).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(29).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(3).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(30).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(31).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(32).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(33).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(34).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(35).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(36).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(37).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(38).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(39).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(4).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(40).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(41).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(42).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(43).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(44).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(45).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(46).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(47).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(48).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(49).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(5).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(50).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(51).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(52).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(53).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(54).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(55).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(56).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(57).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(58).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(59).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(6).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(60).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(61).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(62).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(63).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(64).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(65).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(66).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(67).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(68).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(69).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(7).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(70).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(71).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(72).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(73).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(74).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(75).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(76).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(77).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(78).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(79).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(8).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(80).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(81).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(82).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(83).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(84).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(85).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(86).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(87).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(88).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(89).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(9).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(90).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(91).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(92).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(93).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(94).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(95).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(96).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(97).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(98).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(99).json
# Processing folder: TL_쇼핑몰_01.패션_1-2.남성의류
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(1).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(10).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(11).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(12).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(13).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(14).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(15).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(16).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(17).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(18).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(19).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(2).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(20).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(21).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(22).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(23).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(24).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(25).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(26).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(27).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(28).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(29).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(3).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(30).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(31).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(32).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(33).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(34).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(35).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(36).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(37).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(38).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(39).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(4).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(40).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(41).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(42).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(43).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(44).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(45).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(46).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(47).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(48).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(49).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(5).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(50).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(51).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(52).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(53).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(54).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(55).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(56).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(57).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(58).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(59).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(6).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(60).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(61).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(62).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(63).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(64).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(65).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(66).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(67).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(68).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(69).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(7).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(70).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(71).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(72).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(73).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(74).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(75).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(76).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(77).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(78).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(79).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(8).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(80).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(9).json
# Processing folder: TL_쇼핑몰_01.패션_1-3.패션슈즈
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(1).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(10).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(11).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(12).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(13).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(14).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(15).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(16).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(17).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(18).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(19).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(2).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(20).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(21).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(22).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(23).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(24).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(25).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(26).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(27).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(28).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(29).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(3).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(30).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(31).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(32).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(33).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(34).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(35).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(36).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(37).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(38).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(39).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(4).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(40).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(41).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(42).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(43).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(44).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(45).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(46).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(47).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(48).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(49).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(5).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(50).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(51).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(52).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(53).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(54).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(55).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(56).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(57).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(58).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(59).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(6).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(60).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(61).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(62).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(63).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(64).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(65).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(66).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(67).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(68).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(69).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(7).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(70).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(71).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(72).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(73).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(74).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(75).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(76).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(77).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(78).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(79).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(8).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(80).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(81).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(82).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(83).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(84).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(85).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(86).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(87).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(88).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(89).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(9).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(90).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(91).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(92).json
# Processing folder: TL_쇼핑몰_01.패션_1-4.잡화
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(1).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(10).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(11).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(12).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(13).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(14).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(15).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(16).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(17).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(18).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(19).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(2).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(20).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(21).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(22).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(23).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(24).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(25).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(26).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(27).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(28).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(29).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(3).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(30).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(31).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(4).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(5).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(6).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(7).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(8).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(9).json
#          Aspect                       SentimentText SentimentWord  \
# 0            가격                             가격이 착하고             2
# 1           디자인                           디자인이 예쁩니다             2
# 2            가격                                  싸고             1
# 3           디자인                            디자인이 예뻐요             2
# 4            가격                         가성비 가심비 입니다             3
# ...         ...                                 ...           ...
# 120211       품질                  바퀴도 크고 부드럽게 잘 움직여서             5
# 120212  사용성/편의성                         편하게 사용하겠어요.             2
# 120213      디자인  캐리어 찾을때도 비슷비슷한 모양들 많은중에 눈에 띌것같네요^^             7
# 120214       색상                            색상도 좋으네요             2
# 120215  사용성/편의성                4종류 용도에 맞게 사용하기 편리해요             5
#
#        SentimentPolarity
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 120211                 1
# 120212                 1
# 120213                 1
# 120214                 1
# 120215                 1
#
# [120216 rows x 4 columns]

# %%
Val_PATH = './DATA/Validation/'
# 여러 폴더 경로를 리스트로 저장
folder_paths = os.listdir(Val_PATH)

# 빈 데이터프레임 리스트 생성
dataframes = []

# 각 폴더 내의 JSON 파일을 읽어와 데이터프레임으로 변환
for folder_path in folder_paths:
    FOLDER_PATH = Val_PATH+folder_path
    print(f"Processing folder: {folder_path}")
    
    # 폴더 내의 모든 JSON 파일 리스트
    json_files = [file for file in os.listdir(FOLDER_PATH) if file.endswith('.json')]

    for file in json_files:
        file_path = os.path.join(FOLDER_PATH, file)
        print(f"Loading file: {file_path}")
        
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
                
                # 파일 내용 확인 및 데이터프레임으로 변환
                if data:
                    # Aspects만 추출
                    for review in data:
                        aspects = pd.json_normalize(review.get('Aspects'))
                        dataframes.append(aspects)
                else:
                    print(f"No data found in {file}")
                    
        except json.JSONDecodeError:
            print(f"Error loading {file}: Invalid JSON")

# 데이터프레임 결합
if dataframes:
    final_dataframe = pd.concat(dataframes, ignore_index=True)
    print(final_dataframe)
else:
    print("No valid dataframes to concatenate.")
final_dataframe.to_csv('./DATA/test.csv')
# Out:
# Processing folder: VL_쇼핑몰_01.패션_1-1.여성의류
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(156).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(157).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(158).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(159).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(160).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(161).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(162).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(163).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(164).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(165).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(166).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(167).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(168).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(169).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(170).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(171).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(172).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(173).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(174).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(175).json
# Processing folder: VL_쇼핑몰_01.패션_1-2.남성의류
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(81).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(82).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(83).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(84).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(85).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(86).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(87).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(88).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(89).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(90).json
# Processing folder: VL_쇼핑몰_01.패션_1-3.패션슈즈
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(100).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(101).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(102).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(103).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(104).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(93).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(94).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(95).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(96).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(97).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(98).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(99).json
# Processing folder: VL_쇼핑몰_01.패션_1-4.잡화
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(32).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(33).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(34).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(35).json
#       Aspect         SentimentText SentimentWord SentimentPolarity
# 0         기능          배도 편하게 눌러주고              3                 1
# 1         길이         미디가 길어 편하다고..             3                 1
# 2         색상     다섯가지 색상 모두 이쁘네요^^             4                 1
# 3         기능             입자마자 시원하고             2                 1
# 4         기능          배 부분도 잘 잡아주고             4                 1
# ...      ...                   ...           ...               ...
# 15755     품질                품질 좋아요             2                 1
# 15756     품질        우선 박음질이 허접합니다.             3                -1
# 15757     색상              색상은 이뻐요              2                 1
# 15758     품질  검정백은 지퍼가 뻑뻑해서 잘 안닫혀요             5                -1
# 15759     가격    50프로 적립 아니였음 반품이였음             4                 1
#
# [15760 rows x 4 columns]

# %%
trainDF=pd.read_csv(r'C:\Users\MSI\Desktop\TORCH_NLP\1010\DATA\train.csv', usecols=[1,2,4])
testDF=pd.read_csv(r'C:\Users\MSI\Desktop\TORCH_NLP\1010\DATA\test.csv',usecols=[1,2,4])

# %%
# 데이터 인코딩 함수
def data_encoding(DF):
    labelCD = DF.Aspect.unique().tolist()                   # Aspect 컬럼의 유니크 값 리스트 
    DF['Aspect'] = DF['Aspect'].map(lambda x: labelCD.index(x))         # 다중 분류 라벨링 인코딩
    DF.loc[DF['SentimentPolarity'] == -1, 'SentimentPolarity'] = 0      # 2진 분류 인코딩
    return DF, labelCD

# %%
# 단어사전 만드는 함수
def build_vocab(corpus, n_vocab, special_tokens):
    counter = Counter()                                     # Counter 인스턴스 생성
    for tokens in corpus:                                   # 입력받은 corpus로 카운터 모델 초기화
        counter.update(tokens)
    vocab = special_tokens.copy()                           
    for token, count in counter.most_common(n_vocab):       # 상위 중복 언어 단어사전에 추가
        vocab.append(token)
    return vocab

# %%
# 패딩함수
def pad_sequences(sequences, max_length, pad_value):
    result = list()
    for sequence in sequences:                              
        sequence = sequence[:max_length]                    # max_length 만큼 자르기
        pad_length = max_length - len(sequence)             # max_length보다 단어가 적다면
        padded_sequence = sequence + [pad_value] * pad_length   # 정해진 수 채우기
        result.append(padded_sequence)
    return np.asarray(result)

# %%
# 자연어 인코딩 함수
def encoding_ids(token_to_id, tokens, unk_id):
    return [
        [token_to_id.get(token, unk_id) for token in review] for review in tokens
    ]   # 자연어 인코딩

# %%
# 학습함수
def model_train(model, datasets, cl_criterion, bn_criterion, optimizer, device, interval):
    model.train()
    losses = []

    for step, (input_ids, labels) in enumerate(datasets):
        input_ids = input_ids.to(device)                    # 인풋데이터
        cl_labels = labels[:, 0].to(device)                 # 라벨 다중분류
        bn_labels = labels[:, 1].to(device).float()         # 라벨 2진분류  (float형)

        # Forward pass
        classesd, logits = model(input_ids)

        # Calculate losses
        loss_cl = cl_criterion(classesd, cl_labels)         # 
        loss_bn = bn_criterion(logits.squeeze(), bn_labels) # 
        loss = loss_cl + loss_bn
        losses.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if step % interval == 0:
            print(f'Train Loss {step} : {np.mean(losses)}')

# %%
# test 함수

def model_test(model, datasets, cl_criterion, bn_criterion, device, epoch, results_df):
    model.eval()
    losses = []
    cl_score = []
    bn_score = []

    with torch.no_grad(): 
        for step, (input_ids, labels) in enumerate(datasets):
            input_ids = input_ids.to(device)
            cl_labels = labels[:, 0].to(device).long()
            bn_labels = labels[:, 1].to(device).float() 

            # Forward pass
            classesd, logits = model(input_ids)

            # Calculate losses
            loss_cl = cl_criterion(classesd, cl_labels)
            loss_bn = bn_criterion(logits.squeeze(), bn_labels)
            loss = loss_cl + loss_bn
            losses.append(loss.item())
            
            # Calculate class accuracy
            cl_predictions = torch.argmax(torch.softmax(classesd, dim=1), dim=1)  # 다중 클래스 예측
            cl_score.extend(cl_predictions.eq(cl_labels).cpu().numpy())  # 정확도 계산
            
            # Calculate binary accuracy
            bn_predictions = (torch.sigmoid(logits) > 0.5).int().squeeze()  # 이진 예측
            bn_score.extend(bn_predictions.eq(bn_labels.int()).cpu().numpy())  # 정확도 계산
        
        # 정확도 계산
        cl_accuracy = np.mean(cl_score)
        bn_accuracy = np.mean(bn_score)
        
        print(f'Epoch {epoch} - Val Loss: {np.mean(losses)}, bn_score Val Accuracy: {bn_accuracy}, cl_score Val Accuracy: {cl_accuracy}')

# %%
# 실행함수
def main():
    N_VOCAB = 5000
    MAX_LENGTH = 10
    EPOCHS =100
    INTERVAL = 500
    BATCH_SIZE = 32
    LR = 0.001
    special_tokens = ['<pad>', '<unk>']

    trainDF, testDF = load_data('./DATA/Train_Fashion_reivew.csv','./DATA/Val_Fashion_reivew.csv')

    trainDF, aspectCD = data_encoding(trainDF)
    testDF, _ = data_encoding(testDF)

    ## 토큰화 및 불용어 처리 ------------------------------------------------------------------------------------------------------------
    punc=string.punctuation

    for p in punc:
        trainDF['SentimentText'] = trainDF['SentimentText'].str.replace(p, '')
        testDF['SentimentText']=testDF['SentimentText'].str.replace(p,'')

    m=re.compile('[^ ㄱ-ㅣ가-힣]+')

    trainDF['SentimentText']=trainDF['SentimentText'].apply(lambda x: m.sub(' ', x))
    testDF['SentimentText']=testDF['SentimentText'].apply(lambda x: m.sub(' ', x))

    stop_word='./stopwords.txt'

    with open(stop_word, 'r', encoding='utf-8') as f:
        stop_words = [line.strip() for line in f]


    tokenizer = Okt()
    train_tokens = [[token for token in tokenizer.morphs(text) if token not in stop_words] for text in trainDF['SentimentText']]
    test_tokens = [[token for token in tokenizer.morphs(text) if token not in stop_words] for text in testDF['SentimentText']]
    # -------------------------------------------------------------------------------------------------------------------------------


    vocab = build_vocab(train_tokens, N_VOCAB, special_tokens)
    token_to_id = {token: idx for idx, token in enumerate(vocab)}
    id_to_token = {idx: token for idx, token in enumerate(vocab)}

    pad_id = token_to_id['<pad>']
    unk_id = token_to_id['<unk>']
    train_ids = encoding_ids(token_to_id, train_tokens, unk_id)
    test_ids = encoding_ids(token_to_id, test_tokens, unk_id)
    train_ids = pad_sequences(train_ids, MAX_LENGTH, pad_id)
    test_ids = pad_sequences(test_ids, MAX_LENGTH, pad_id)

    # 텐서화
    train_ids = torch.tensor(train_ids, dtype=torch.long)
    test_ids = torch.tensor(test_ids, dtype=torch.long)

    # 레이블 텐서화
    train_labels = torch.tensor(list(zip(trainDF['Aspect'].values, trainDF['SentimentPolarity'].values)), dtype=torch.long)
    test_labels = torch.tensor(list(zip(testDF['Aspect'].values, testDF['SentimentPolarity'].values)), dtype=torch.float32)

    # 데이터셋 생성
    train_dataset = TensorDataset(train_ids, train_labels)
    test_dataset = TensorDataset(test_ids, test_labels)

    # 데이터 로더 생성
    train_loader = DataLoader(train_dataset, BATCH_SIZE, shuffle=True)
    test_loader = DataLoader(test_dataset, BATCH_SIZE, shuffle=False)

    # 모델 초기화
    n_vocab = len(token_to_id)  # 어휘 크기 계산
    hidden_dim = 64 
    embedding_dim = 128
    n_layers = 2
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    classifier = reviewClassifierModel(
        n_vocab=n_vocab, hidden_dim=hidden_dim, embedding_dim=embedding_dim, n_classes=len(aspectCD), n_layers=n_layers
    ).to(device)

    # 손실 함수 및 최적화기 설정
    cl_criterion = nn.NLLLoss().to(device)
    bn_criterion = nn.BCEWithLogitsLoss().to(device)
    optimizer = optim.RMSprop(classifier.parameters(), lr=LR)


    # 결과를 저장할 DataFrame 생성
    results_df = pd.DataFrame(columns=['Val Loss', 'bn_score Val Accuracy', 'cl_score Val Accuracy'])

    for epoch in range(EPOCHS):
        model_train(classifier, train_loader, cl_criterion, bn_criterion, optimizer, device, INTERVAL)
        model_test(classifier, test_loader, cl_criterion, bn_criterion, device, epoch, results_df)  # DataFrame 전달

        # 모델 저장 (에포크 번호 추가)
        model_save_path = f'./saved_model/review_classifier_epoch_{epoch + 1}.pt'  # 에포크 번호 포함
        torch.save(classifier.state_dict(), model_save_path)
        print(f'Model saved at {model_save_path}')

    # 결과 DataFrame 저장
    results_df.to_csv('./saved_model/evaluation_results.csv', index=True)
    print("평가 결과가 저장되었습니다.")

# %%
TRAIN_PATH = './DATA/Training/'
# 여러 폴더 경로를 리스트로 저장
folder_paths = os.listdir(TRAIN_PATH)

# 빈 데이터프레임 리스트 생성
dataframes = []

# 각 폴더 내의 JSON 파일을 읽어와 데이터프레임으로 변환
for folder_path in folder_paths:
    FOLDER_PATH = TRAIN_PATH+folder_path
    print(f"Processing folder: {folder_path}")
    
    # 폴더 내의 모든 JSON 파일 리스트
    json_files = [file for file in os.listdir(FOLDER_PATH) if file.endswith('.json')]

    for file in json_files:
        file_path = os.path.join(FOLDER_PATH, file)
        print(f"Loading file: {file_path}")
        
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
                
                # 파일 내용 확인 및 데이터프레임으로 변환
                if data:
                    # Aspects만 추출
                    for review in data:
                        aspects = pd.json_normalize(review.get('Aspects'))
                        dataframes.append(aspects)
                else:
                    print(f"No data found in {file}")
                    
        except json.JSONDecodeError:
            print(f"Error loading {file}: Invalid JSON")

# 데이터프레임 결합
if dataframes:
    final_dataframe = pd.concat(dataframes, ignore_index=True)
    print(final_dataframe)
else:
    print("No valid dataframes to concatenate.")
final_dataframe.to_csv('./DATA/Train_Fashion_reivew.csv')
Val_PATH = './DATA/Validation/'
# 여러 폴더 경로를 리스트로 저장
folder_paths = os.listdir(Val_PATH)

# 빈 데이터프레임 리스트 생성
dataframes = []

# 각 폴더 내의 JSON 파일을 읽어와 데이터프레임으로 변환
for folder_path in folder_paths:
    FOLDER_PATH = Val_PATH+folder_path
    print(f"Processing folder: {folder_path}")
    
    # 폴더 내의 모든 JSON 파일 리스트
    json_files = [file for file in os.listdir(FOLDER_PATH) if file.endswith('.json')]

    for file in json_files:
        file_path = os.path.join(FOLDER_PATH, file)
        print(f"Loading file: {file_path}")
        
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
                
                # 파일 내용 확인 및 데이터프레임으로 변환
                if data:
                    # Aspects만 추출
                    for review in data:
                        aspects = pd.json_normalize(review.get('Aspects'))
                        dataframes.append(aspects)
                else:
                    print(f"No data found in {file}")
                    
        except json.JSONDecodeError:
            print(f"Error loading {file}: Invalid JSON")

# 데이터프레임 결합
if dataframes:
    final_dataframe = pd.concat(dataframes, ignore_index=True)
    print(final_dataframe)
else:
    print("No valid dataframes to concatenate.")
final_dataframe.to_csv('./DATA/Val_Fashion_reivew.csv')
# Out:
# Processing folder: TL_쇼핑몰_01.패션_1-1.여성의류
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(1).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(10).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(100).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(101).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(102).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(103).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(104).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(105).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(106).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(107).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(108).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(109).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(11).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(110).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(111).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(112).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(113).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(114).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(115).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(116).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(117).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(118).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(119).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(12).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(120).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(121).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(122).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(123).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(124).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(125).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(126).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(127).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(128).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(129).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(13).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(130).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(131).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(132).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(133).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(134).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(135).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(136).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(137).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(138).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(139).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(14).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(140).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(141).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(142).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(143).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(144).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(145).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(146).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(147).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(148).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(149).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(15).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(150).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(151).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(152).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(153).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(154).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(155).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(16).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(17).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(18).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(19).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(2).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(20).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(21).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(22).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(23).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(24).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(25).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(26).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(27).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(28).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(29).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(3).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(30).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(31).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(32).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(33).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(34).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(35).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(36).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(37).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(38).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(39).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(4).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(40).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(41).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(42).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(43).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(44).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(45).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(46).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(47).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(48).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(49).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(5).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(50).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(51).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(52).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(53).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(54).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(55).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(56).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(57).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(58).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(59).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(6).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(60).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(61).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(62).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(63).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(64).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(65).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(66).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(67).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(68).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(69).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(7).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(70).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(71).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(72).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(73).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(74).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(75).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(76).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(77).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(78).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(79).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(8).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(80).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(81).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(82).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(83).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(84).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(85).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(86).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(87).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(88).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(89).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(9).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(90).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(91).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(92).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(93).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(94).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(95).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(96).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(97).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(98).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(99).json
# Processing folder: TL_쇼핑몰_01.패션_1-2.남성의류
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(1).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(10).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(11).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(12).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(13).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(14).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(15).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(16).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(17).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(18).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(19).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(2).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(20).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(21).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(22).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(23).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(24).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(25).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(26).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(27).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(28).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(29).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(3).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(30).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(31).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(32).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(33).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(34).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(35).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(36).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(37).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(38).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(39).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(4).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(40).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(41).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(42).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(43).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(44).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(45).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(46).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(47).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(48).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(49).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(5).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(50).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(51).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(52).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(53).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(54).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(55).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(56).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(57).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(58).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(59).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(6).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(60).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(61).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(62).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(63).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(64).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(65).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(66).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(67).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(68).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(69).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(7).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(70).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(71).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(72).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(73).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(74).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(75).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(76).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(77).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(78).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(79).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(8).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(80).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(9).json
# Processing folder: TL_쇼핑몰_01.패션_1-3.패션슈즈
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(1).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(10).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(11).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(12).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(13).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(14).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(15).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(16).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(17).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(18).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(19).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(2).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(20).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(21).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(22).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(23).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(24).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(25).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(26).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(27).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(28).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(29).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(3).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(30).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(31).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(32).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(33).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(34).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(35).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(36).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(37).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(38).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(39).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(4).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(40).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(41).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(42).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(43).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(44).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(45).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(46).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(47).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(48).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(49).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(5).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(50).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(51).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(52).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(53).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(54).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(55).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(56).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(57).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(58).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(59).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(6).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(60).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(61).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(62).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(63).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(64).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(65).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(66).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(67).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(68).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(69).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(7).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(70).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(71).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(72).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(73).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(74).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(75).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(76).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(77).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(78).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(79).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(8).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(80).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(81).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(82).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(83).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(84).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(85).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(86).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(87).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(88).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(89).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(9).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(90).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(91).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(92).json
# Processing folder: TL_쇼핑몰_01.패션_1-4.잡화
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(1).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(10).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(11).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(12).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(13).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(14).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(15).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(16).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(17).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(18).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(19).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(2).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(20).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(21).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(22).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(23).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(24).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(25).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(26).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(27).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(28).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(29).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(3).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(30).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(31).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(4).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(5).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(6).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(7).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(8).json
# Loading file: ./DATA/Training/TL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(9).json
#          Aspect                       SentimentText SentimentWord  \
# 0            가격                             가격이 착하고             2
# 1           디자인                           디자인이 예쁩니다             2
# 2            가격                                  싸고             1
# 3           디자인                            디자인이 예뻐요             2
# 4            가격                         가성비 가심비 입니다             3
# ...         ...                                 ...           ...
# 120211       품질                  바퀴도 크고 부드럽게 잘 움직여서             5
# 120212  사용성/편의성                         편하게 사용하겠어요.             2
# 120213      디자인  캐리어 찾을때도 비슷비슷한 모양들 많은중에 눈에 띌것같네요^^             7
# 120214       색상                            색상도 좋으네요             2
# 120215  사용성/편의성                4종류 용도에 맞게 사용하기 편리해요             5
#
#        SentimentPolarity
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 120211                 1
# 120212                 1
# 120213                 1
# 120214                 1
# 120215                 1
#
# [120216 rows x 4 columns]
# Processing folder: VL_쇼핑몰_01.패션_1-1.여성의류
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(156).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(157).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(158).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(159).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(160).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(161).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(162).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(163).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(164).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(165).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(166).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(167).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(168).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(169).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(170).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(171).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(172).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(173).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(174).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-1.여성의류\1-1.여성의류(175).json
# Processing folder: VL_쇼핑몰_01.패션_1-2.남성의류
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(81).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(82).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(83).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(84).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(85).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(86).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(87).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(88).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(89).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-2.남성의류\1-2.남성의류(90).json
# Processing folder: VL_쇼핑몰_01.패션_1-3.패션슈즈
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(100).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(101).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(102).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(103).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(104).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(93).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(94).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(95).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(96).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(97).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(98).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-3.패션슈즈\1-3.패션슈즈(99).json
# Processing folder: VL_쇼핑몰_01.패션_1-4.잡화
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(32).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(33).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(34).json
# Loading file: ./DATA/Validation/VL_쇼핑몰_01.패션_1-4.잡화\1-4.잡화(35).json
#       Aspect         SentimentText SentimentWord SentimentPolarity
# 0         기능          배도 편하게 눌러주고              3                 1
# 1         길이         미디가 길어 편하다고..             3                 1
# 2         색상     다섯가지 색상 모두 이쁘네요^^             4                 1
# 3         기능             입자마자 시원하고             2                 1
# 4         기능          배 부분도 잘 잡아주고             4                 1
# ...      ...                   ...           ...               ...
# 15755     품질                품질 좋아요             2                 1
# 15756     품질        우선 박음질이 허접합니다.             3                -1
# 15757     색상              색상은 이뻐요              2                 1
# 15758     품질  검정백은 지퍼가 뻑뻑해서 잘 안닫혀요             5                -1
# 15759     가격    50프로 적립 아니였음 반품이였음             4                 1
#
# [15760 rows x 4 columns]

# %%
main()
# Out:
# Train Loss 0 : 3.9773545265197754
# Train Loss 500 : 2.8104467913062274
# Train Loss 1000 : 2.44828752335254
# Train Loss 1500 : 2.2350388168891535
# Train Loss 2000 : 2.078799213009557
# Train Loss 2500 : 1.9664365617049688
# Train Loss 3000 : 1.877734921944614
# Train Loss 3500 : 1.8073209827030021
# Epoch 0 - Val Loss: 6.788484554503559, bn_score Val Accuracy: 0.8706218274111676, cl_score Val Accuracy: 0.0450507614213198
# Model saved at ./saved_model/review_classifier_epoch_1.pt
# Train Loss 0 : 1.1909698247909546
# Train Loss 500 : 1.238012807216949
# Train Loss 1000 : 1.221825931098435
# Train Loss 1500 : 1.2038205783816673
# Train Loss 2000 : 1.194732441254582
# Train Loss 2500 : 1.1818323938882813
# Train Loss 3000 : 1.1723040420089075
# Train Loss 3500 : 1.1620991700327556
# Epoch 1 - Val Loss: 7.243276842709245, bn_score Val Accuracy: 0.8893401015228426, cl_score Val Accuracy: 0.058248730964467005
# Model saved at ./saved_model/review_classifier_epoch_2.pt
# Train Loss 0 : 1.1248247623443604
# Train Loss 500 : 1.0044799131785562
# Train Loss 1000 : 1.0015355668939672
# Train Loss 1500 : 1.001428635834377
# Train Loss 2000 : 0.9971399373676942
# Train Loss 2500 : 0.9948933137054207
# Train Loss 3000 : 0.9950871491424246
# Train Loss 3500 : 0.9947865731084187
# Epoch 2 - Val Loss: 7.427833841973821, bn_score Val Accuracy: 0.9029187817258884, cl_score Val Accuracy: 0.060088832487309646
# Model saved at ./saved_model/review_classifier_epoch_3.pt
# Train Loss 0 : 0.8901009559631348
# Train Loss 500 : 0.8724991513821417
# Train Loss 1000 : 0.8949518150144762
# Train Loss 1500 : 0.8932567972052026
# Train Loss 2000 : 0.8958312812922657
# Train Loss 2500 : 0.8932089339204428
# Train Loss 3000 : 0.893721425326734
# Train Loss 3500 : 0.8959096423883637
# Epoch 3 - Val Loss: 7.736322192584767, bn_score Val Accuracy: 0.9045685279187817, cl_score Val Accuracy: 0.05241116751269036
# Model saved at ./saved_model/review_classifier_epoch_4.pt
# Train Loss 0 : 1.1799603700637817
# Train Loss 500 : 0.8327680288139218
# Train Loss 1000 : 0.8211641602374457
# Train Loss 1500 : 0.8233104467014724
# Train Loss 2000 : 0.8249681093867334
# Train Loss 2500 : 0.8280796213287775
# Train Loss 3000 : 0.8295926594537563
# Train Loss 3500 : 0.8296620545771012
# Epoch 4 - Val Loss: 7.898733815121602, bn_score Val Accuracy: 0.9015228426395939, cl_score Val Accuracy: 0.05348984771573604
# Model saved at ./saved_model/review_classifier_epoch_5.pt
# Train Loss 0 : 0.3574557304382324
# Train Loss 500 : 0.7649182800404326
# Train Loss 1000 : 0.7680597207197299
# Train Loss 1500 : 0.7681902374111756
# Train Loss 2000 : 0.7746549662666163
# Train Loss 2500 : 0.7774298304810328
# Train Loss 3000 : 0.7777336380583808
# Train Loss 3500 : 0.7795292462656682
# Epoch 5 - Val Loss: 7.950201969843124, bn_score Val Accuracy: 0.9046319796954315, cl_score Val Accuracy: 0.060279187817258884
# Model saved at ./saved_model/review_classifier_epoch_6.pt
# Train Loss 0 : 0.6134756803512573
# Train Loss 500 : 0.7202443449856516
# Train Loss 1000 : 0.7205796859242938
# Train Loss 1500 : 0.7290048828369613
# Train Loss 2000 : 0.7326701695563971
# Train Loss 2500 : 0.7346830945082161
# Train Loss 3000 : 0.7387224963528838
# Train Loss 3500 : 0.7434114288199257
# Epoch 6 - Val Loss: 8.142081156705505, bn_score Val Accuracy: 0.9062182741116751, cl_score Val Accuracy: 0.05996192893401015
# Model saved at ./saved_model/review_classifier_epoch_7.pt
# Train Loss 0 : 0.48334699869155884
# Train Loss 500 : 0.6893715304945282
# Train Loss 1000 : 0.7013287783026338
# Train Loss 1500 : 0.7005589540345442
# Train Loss 2000 : 0.704936167751176
# Train Loss 2500 : 0.7079808704081367
# Train Loss 3000 : 0.708215803558411
# Train Loss 3500 : 0.7093140426124038
# Epoch 7 - Val Loss: 8.413329191188542, bn_score Val Accuracy: 0.9063451776649746, cl_score Val Accuracy: 0.06046954314720812
# Model saved at ./saved_model/review_classifier_epoch_8.pt
# Train Loss 0 : 0.508231520652771
# Train Loss 500 : 0.645883382586186
# Train Loss 1000 : 0.6574250374074939
# Train Loss 1500 : 0.6605792284547926
# Train Loss 2000 : 0.666810393966418
# Train Loss 2500 : 0.6744999749357344
# Train Loss 3000 : 0.6750387171781767
# Train Loss 3500 : 0.6780293836138378
# Epoch 8 - Val Loss: 8.30865140860753, bn_score Val Accuracy: 0.9071700507614213, cl_score Val Accuracy: 0.054885786802030455
# Model saved at ./saved_model/review_classifier_epoch_9.pt
# Train Loss 0 : 0.4044685363769531
# Train Loss 500 : 0.6407219758647644
# Train Loss 1000 : 0.6298406649451632
# Train Loss 1500 : 0.6311803353400647
# Train Loss 2000 : 0.6400097779471656
# Train Loss 2500 : 0.64660041998835
# Train Loss 3000 : 0.6512524742199873
# Train Loss 3500 : 0.6520763852236374
# Epoch 9 - Val Loss: 8.9041831449853, bn_score Val Accuracy: 0.9064720812182742, cl_score Val Accuracy: 0.06453045685279188
# Model saved at ./saved_model/review_classifier_epoch_10.pt
# Train Loss 0 : 0.46594446897506714
# Train Loss 500 : 0.5995203089749742
# Train Loss 1000 : 0.6081030794254669
# Train Loss 1500 : 0.6088756781609991
# Train Loss 2000 : 0.6162648158765089
# Train Loss 2500 : 0.6213784179226106
# Train Loss 3000 : 0.6266726201318853
# Train Loss 3500 : 0.6288452829460149
# Epoch 10 - Val Loss: 8.779947172555673, bn_score Val Accuracy: 0.9083756345177665, cl_score Val Accuracy: 0.058248730964467005
# Model saved at ./saved_model/review_classifier_epoch_11.pt
# Train Loss 0 : 1.0198034048080444
# Train Loss 500 : 0.5878636678476296
# Train Loss 1000 : 0.5819306304970464
# Train Loss 1500 : 0.5863905613776607
# Train Loss 2000 : 0.5921204482418844
# Train Loss 2500 : 0.5962124700572003
# Train Loss 3000 : 0.6002098250884645
# Train Loss 3500 : 0.6058641277238731
# Epoch 11 - Val Loss: 8.994945990386405, bn_score Val Accuracy: 0.9065355329949238, cl_score Val Accuracy: 0.0575507614213198
# Model saved at ./saved_model/review_classifier_epoch_12.pt
# Train Loss 0 : 0.39124709367752075
# Train Loss 500 : 0.5487978022820698
# Train Loss 1000 : 0.5600028597078957
# Train Loss 1500 : 0.5712633925892765
# Train Loss 2000 : 0.5750561834521022
# Train Loss 2500 : 0.5794119366386183
# Train Loss 3000 : 0.5820968990319373
# Train Loss 3500 : 0.586216293466888
# Epoch 12 - Val Loss: 9.121549037600628, bn_score Val Accuracy: 0.9026649746192893, cl_score Val Accuracy: 0.05862944162436548
# Model saved at ./saved_model/review_classifier_epoch_13.pt
# Train Loss 0 : 0.5052363872528076
# Train Loss 500 : 0.5433388287108577
# Train Loss 1000 : 0.5580784289108647
# Train Loss 1500 : 0.5591697935399653
# Train Loss 2000 : 0.5602184545689973
# Train Loss 2500 : 0.5641530141687212
# Train Loss 3000 : 0.5669447588959323
# Train Loss 3500 : 0.5695224834706606
# Epoch 13 - Val Loss: 9.27761653664146, bn_score Val Accuracy: 0.9049492385786801, cl_score Val Accuracy: 0.05996192893401015
# Model saved at ./saved_model/review_classifier_epoch_14.pt
# Train Loss 0 : 0.30254310369491577
# Train Loss 500 : 0.5138652819448603
# Train Loss 1000 : 0.5335922060640422
# Train Loss 1500 : 0.5374767242035494
# Train Loss 2000 : 0.5407020250509406
# Train Loss 2500 : 0.5468824388253026
# Train Loss 3000 : 0.5493112707989131
# Train Loss 3500 : 0.5516441912076127
# Epoch 14 - Val Loss: 9.34492362198433, bn_score Val Accuracy: 0.9059644670050762, cl_score Val Accuracy: 0.05685279187817259
# Model saved at ./saved_model/review_classifier_epoch_15.pt
# Train Loss 0 : 0.42313098907470703
# Train Loss 500 : 0.4925257548719585
# Train Loss 1000 : 0.5065621199173765
# Train Loss 1500 : 0.5107736473507202
# Train Loss 2000 : 0.5185852581332588
# Train Loss 2500 : 0.5223135101359065
# Train Loss 3000 : 0.5271271031842714
# Train Loss 3500 : 0.533195782770977
# Epoch 15 - Val Loss: 9.115564229280421, bn_score Val Accuracy: 0.9046319796954315, cl_score Val Accuracy: 0.05831218274111675
# Model saved at ./saved_model/review_classifier_epoch_16.pt
# Train Loss 0 : 0.29609066247940063
# Train Loss 500 : 0.4892365126731153
# Train Loss 1000 : 0.49987410754337536
# Train Loss 1500 : 0.5067808074649575
# Train Loss 2000 : 0.5095055794240028
# Train Loss 2500 : 0.5145883683289518
# Train Loss 3000 : 0.5196281137582323
# Train Loss 3500 : 0.5234254409799284
# Epoch 16 - Val Loss: 9.470955796464219, bn_score Val Accuracy: 0.9045050761421319, cl_score Val Accuracy: 0.05970812182741117
# Model saved at ./saved_model/review_classifier_epoch_17.pt
# Train Loss 0 : 0.2459026575088501
# Train Loss 500 : 0.48793729418468573
# Train Loss 1000 : 0.4933964131580485
# Train Loss 1500 : 0.49611582315659064
# Train Loss 2000 : 0.4996158167131539
# Train Loss 2500 : 0.5027407603990026
# Train Loss 3000 : 0.5078849744936778
# Train Loss 3500 : 0.5121665278466148
# Epoch 17 - Val Loss: 9.773103015659789, bn_score Val Accuracy: 0.902982233502538, cl_score Val Accuracy: 0.060088832487309646
# Model saved at ./saved_model/review_classifier_epoch_18.pt
# Train Loss 0 : 0.7245872020721436
# Train Loss 500 : 0.4748477120465504
# Train Loss 1000 : 0.47956996307997674
# Train Loss 1500 : 0.48334152753564774
# Train Loss 2000 : 0.48735116064168704
# Train Loss 2500 : 0.4944361941095759
# Train Loss 3000 : 0.4962251722447696
# Train Loss 3500 : 0.4989259936685853
# Epoch 18 - Val Loss: 9.707536965306343, bn_score Val Accuracy: 0.9055837563451776, cl_score Val Accuracy: 0.053934010152284266
# Model saved at ./saved_model/review_classifier_epoch_19.pt
# Train Loss 0 : 0.3357136845588684
# Train Loss 500 : 0.4685184234779276
# Train Loss 1000 : 0.46500745414198935
# Train Loss 1500 : 0.4662006281261679
# Train Loss 2000 : 0.4693655302261246
# Train Loss 2500 : 0.4735298269703502
# Train Loss 3000 : 0.4790151819924401
# Train Loss 3500 : 0.48618664268603223
# Epoch 19 - Val Loss: 9.793365171908365, bn_score Val Accuracy: 0.9025380710659898, cl_score Val Accuracy: 0.05761421319796954
# Model saved at ./saved_model/review_classifier_epoch_20.pt
# Train Loss 0 : 0.544579267501831
# Train Loss 500 : 0.4584275079136361
# Train Loss 1000 : 0.4682654737681895
# Train Loss 1500 : 0.467716481241284
# Train Loss 2000 : 0.46630845551399036
# Train Loss 2500 : 0.4726462532989219
# Train Loss 3000 : 0.4767282793111541
# Train Loss 3500 : 0.4787621286784673
# Epoch 20 - Val Loss: 10.132404644639207, bn_score Val Accuracy: 0.9013959390862945, cl_score Val Accuracy: 0.057741116751269035
# Model saved at ./saved_model/review_classifier_epoch_21.pt
# Train Loss 0 : 0.47175219655036926
# Train Loss 500 : 0.4498519145115883
# Train Loss 1000 : 0.44391049172256614
# Train Loss 1500 : 0.45086114856598775
# Train Loss 2000 : 0.4561631840610433
# Train Loss 2500 : 0.46173532443885945
# Train Loss 3000 : 0.46559427997611913
# Train Loss 3500 : 0.4667754938809472
# Epoch 21 - Val Loss: 9.908177651449826, bn_score Val Accuracy: 0.901269035532995, cl_score Val Accuracy: 0.06288071065989848
# Model saved at ./saved_model/review_classifier_epoch_22.pt
# Train Loss 0 : 0.8836331963539124
# Train Loss 500 : 0.4413607898883953
# Train Loss 1000 : 0.449039878299484
# Train Loss 1500 : 0.44937828001501084
# Train Loss 2000 : 0.4480037178540754
# Train Loss 2500 : 0.44879133981473446
# Train Loss 3000 : 0.4498920057469191
# Train Loss 3500 : 0.45491930233967437
# Epoch 22 - Val Loss: 10.233130314770866, bn_score Val Accuracy: 0.9004441624365482, cl_score Val Accuracy: 0.06491116751269035
# Model saved at ./saved_model/review_classifier_epoch_23.pt
# Train Loss 0 : 0.2542456090450287
# Train Loss 500 : 0.4355991264570973
# Train Loss 1000 : 0.4361750822622221
# Train Loss 1500 : 0.43557959102555804
# Train Loss 2000 : 0.4389854629171723
# Train Loss 2500 : 0.4427662781480311
# Train Loss 3000 : 0.4456690457916109
# Train Loss 3500 : 0.4477681442690863
# Epoch 23 - Val Loss: 10.42725089790855, bn_score Val Accuracy: 0.9001903553299493, cl_score Val Accuracy: 0.06510152284263959
# Model saved at ./saved_model/review_classifier_epoch_24.pt
# Train Loss 0 : 0.14788071811199188
# Train Loss 500 : 0.41851875585264076
# Train Loss 1000 : 0.4208849706202299
# Train Loss 1500 : 0.42555213190719415
# Train Loss 2000 : 0.43017368671158024
# Train Loss 2500 : 0.4341772245239468
# Train Loss 3000 : 0.4380209071537488
# Train Loss 3500 : 0.4401703671555167
# Epoch 24 - Val Loss: 10.272806025421886, bn_score Val Accuracy: 0.9016497461928934, cl_score Val Accuracy: 0.06097715736040609
# Model saved at ./saved_model/review_classifier_epoch_25.pt
# Train Loss 0 : 0.609865128993988
# Train Loss 500 : 0.4050347585372344
# Train Loss 1000 : 0.4174646202709291
# Train Loss 1500 : 0.4202096761613191
# Train Loss 2000 : 0.4230111784998445
# Train Loss 2500 : 0.42878360520364617
# Train Loss 3000 : 0.4322036633473442
# Train Loss 3500 : 0.43541735800137965
# Epoch 25 - Val Loss: 10.452112932959627, bn_score Val Accuracy: 0.8985406091370558, cl_score Val Accuracy: 0.057487309644670054
# Model saved at ./saved_model/review_classifier_epoch_26.pt
# Train Loss 0 : 0.2585465908050537
# Train Loss 500 : 0.4023997870435615
# Train Loss 1000 : 0.40637821187967665
# Train Loss 1500 : 0.4110046960314181
# Train Loss 2000 : 0.41413771537044597
# Train Loss 2500 : 0.41973180582568864
# Train Loss 3000 : 0.4232848552190654
# Train Loss 3500 : 0.425741630618324
# Epoch 26 - Val Loss: 10.448653947509085, bn_score Val Accuracy: 0.9010786802030457, cl_score Val Accuracy: 0.05799492385786802
# Model saved at ./saved_model/review_classifier_epoch_27.pt
# Train Loss 0 : 0.6240432262420654
# Train Loss 500 : 0.38768047605178313
# Train Loss 1000 : 0.39707547103563745
# Train Loss 1500 : 0.40405039279551047
# Train Loss 2000 : 0.40926605998456983
# Train Loss 2500 : 0.41230423860281695
# Train Loss 3000 : 0.41444153500853065
# Train Loss 3500 : 0.41763792832703106
# Epoch 27 - Val Loss: 10.661822879048438, bn_score Val Accuracy: 0.899492385786802, cl_score Val Accuracy: 0.06015228426395939
# Model saved at ./saved_model/review_classifier_epoch_28.pt
# Train Loss 0 : 0.3480740189552307
# Train Loss 500 : 0.3811739511237649
# Train Loss 1000 : 0.40370994965572815
# Train Loss 1500 : 0.4006385747132343
# Train Loss 2000 : 0.40747721977289886
# Train Loss 2500 : 0.41030497122101667
# Train Loss 3000 : 0.4134108262811252
# Train Loss 3500 : 0.4158548940546647
# Epoch 28 - Val Loss: 10.894522422225673, bn_score Val Accuracy: 0.8995558375634518, cl_score Val Accuracy: 0.05767766497461929
# Model saved at ./saved_model/review_classifier_epoch_29.pt
# Train Loss 0 : 0.6379061341285706
# Train Loss 500 : 0.3832633653562702
# Train Loss 1000 : 0.39704851691167314
# Train Loss 1500 : 0.40194487633763115
# Train Loss 2000 : 0.40362794936328816
# Train Loss 2500 : 0.4024441100996597
# Train Loss 3000 : 0.404363683775261
# Train Loss 3500 : 0.4087995798868372
# Epoch 29 - Val Loss: 10.886480992996185, bn_score Val Accuracy: 0.8989213197969543, cl_score Val Accuracy: 0.06408629441624365
# Model saved at ./saved_model/review_classifier_epoch_30.pt
# Train Loss 0 : 0.18705600500106812
# Train Loss 500 : 0.38795196041910945
# Train Loss 1000 : 0.3894214105311331
# Train Loss 1500 : 0.39266556100814365
# Train Loss 2000 : 0.3972178926130106
# Train Loss 2500 : 0.39819995441087863
# Train Loss 3000 : 0.4025529752429904
# Train Loss 3500 : 0.40420772713470443
# Epoch 30 - Val Loss: 10.701998967911603, bn_score Val Accuracy: 0.8981598984771574, cl_score Val Accuracy: 0.06269035532994924
# Model saved at ./saved_model/review_classifier_epoch_31.pt
# Train Loss 0 : 0.3047454357147217
# Train Loss 500 : 0.3518810765873529
# Train Loss 1000 : 0.3732553595243455
# Train Loss 1500 : 0.37493103753767915
# Train Loss 2000 : 0.3810717157483369
# Train Loss 2500 : 0.3895904574199158
# Train Loss 3000 : 0.3948259370358675
# Train Loss 3500 : 0.40043476559445196
# Epoch 31 - Val Loss: 10.89579649629264, bn_score Val Accuracy: 0.8988578680203045, cl_score Val Accuracy: 0.06453045685279188
# Model saved at ./saved_model/review_classifier_epoch_32.pt
# Train Loss 0 : 0.31284433603286743
# Train Loss 500 : 0.3774978628608876
# Train Loss 1000 : 0.3725699119895071
# Train Loss 1500 : 0.37758118969988297
# Train Loss 2000 : 0.3825558042046667
# Train Loss 2500 : 0.385719781471152
# Train Loss 3000 : 0.38984182965965003
# Train Loss 3500 : 0.392868989395971
# Epoch 32 - Val Loss: 11.057481811206191, bn_score Val Accuracy: 0.8979060913705583, cl_score Val Accuracy: 0.06046954314720812
# Model saved at ./saved_model/review_classifier_epoch_33.pt
# Train Loss 0 : 0.18607176840305328
# Train Loss 500 : 0.3675598832230249
# Train Loss 1000 : 0.37473498222666546
# Train Loss 1500 : 0.3748677670881202
# Train Loss 2000 : 0.3767070732750129
# Train Loss 2500 : 0.37945748879903796
# Train Loss 3000 : 0.3826485455510359
# Train Loss 3500 : 0.3871613145885434
# Epoch 33 - Val Loss: 10.85223885046783, bn_score Val Accuracy: 0.8979060913705583, cl_score Val Accuracy: 0.05653553299492386
# Model saved at ./saved_model/review_classifier_epoch_34.pt
# Train Loss 0 : 0.13556067645549774
# Train Loss 500 : 0.361552318606429
# Train Loss 1000 : 0.36435746702251137
# Train Loss 1500 : 0.36997404713171234
# Train Loss 2000 : 0.37559529507289763
# Train Loss 2500 : 0.3811324240475214
# Train Loss 3000 : 0.38500859154532924
# Train Loss 3500 : 0.3877988292398588
# Epoch 34 - Val Loss: 11.42175792438747, bn_score Val Accuracy: 0.8986675126903553, cl_score Val Accuracy: 0.06364213197969543
# Model saved at ./saved_model/review_classifier_epoch_35.pt
# Train Loss 0 : 0.27747806906700134
# Train Loss 500 : 0.3591050213414752
# Train Loss 1000 : 0.3648543596811049
# Train Loss 1500 : 0.36930770202130975
# Train Loss 2000 : 0.3697226664636923
# Train Loss 2500 : 0.3744184965582811
# Train Loss 3000 : 0.3768923793910385
# Train Loss 3500 : 0.3803838562966244
# Epoch 35 - Val Loss: 11.13237676659172, bn_score Val Accuracy: 0.8969543147208122, cl_score Val Accuracy: 0.05564720812182741
# Model saved at ./saved_model/review_classifier_epoch_36.pt
# Train Loss 0 : 0.43391987681388855
# Train Loss 500 : 0.3613498988979591
# Train Loss 1000 : 0.36632632561675554
# Train Loss 1500 : 0.37377096801936666
# Train Loss 2000 : 0.37283387769391574
# Train Loss 2500 : 0.3787507376909518
# Train Loss 3000 : 0.3799439730139444
# Train Loss 3500 : 0.3802032825749573
# Epoch 36 - Val Loss: 11.271073444861669, bn_score Val Accuracy: 0.8967005076142132, cl_score Val Accuracy: 0.05532994923857868
# Model saved at ./saved_model/review_classifier_epoch_37.pt
# Train Loss 0 : 0.4072864055633545
# Train Loss 500 : 0.35784149842109986
# Train Loss 1000 : 0.3580526731030031
# Train Loss 1500 : 0.36608150757248603
# Train Loss 2000 : 0.3701114707627799
# Train Loss 2500 : 0.3731281575461963
# Train Loss 3000 : 0.3749343183696002
# Train Loss 3500 : 0.37664538472560993
# Epoch 37 - Val Loss: 11.465389072774148, bn_score Val Accuracy: 0.896256345177665, cl_score Val Accuracy: 0.06370558375634518
# Model saved at ./saved_model/review_classifier_epoch_38.pt
# Train Loss 0 : 0.25597426295280457
# Train Loss 500 : 0.34348344866803543
# Train Loss 1000 : 0.3558676151836014
# Train Loss 1500 : 0.36256495711060466
# Train Loss 2000 : 0.3658638265093734
# Train Loss 2500 : 0.36633806135944846
# Train Loss 3000 : 0.36946836297959834
# Train Loss 3500 : 0.37186673472076015
# Epoch 38 - Val Loss: 11.284373444911191, bn_score Val Accuracy: 0.8975888324873097, cl_score Val Accuracy: 0.06510152284263959
# Model saved at ./saved_model/review_classifier_epoch_39.pt
# Train Loss 0 : 0.5892962217330933
# Train Loss 500 : 0.34139667818705716
# Train Loss 1000 : 0.34435813559161554
# Train Loss 1500 : 0.3527929164335221
# Train Loss 2000 : 0.35829244333615845
# Train Loss 2500 : 0.3636574581390569
# Train Loss 3000 : 0.3649492251256314
# Train Loss 3500 : 0.3688705003868509
# Epoch 39 - Val Loss: 11.610417431798474, bn_score Val Accuracy: 0.8940989847715736, cl_score Val Accuracy: 0.05685279187817259
# Model saved at ./saved_model/review_classifier_epoch_40.pt
# Train Loss 0 : 0.3317509889602661
# Train Loss 500 : 0.336807512088926
# Train Loss 1000 : 0.3466260921690133
# Train Loss 1500 : 0.34676795372916885
# Train Loss 2000 : 0.3483737481107329
# Train Loss 2500 : 0.3525429154794271
# Train Loss 3000 : 0.359098812476451
# Train Loss 3500 : 0.36232773142754265
# Epoch 40 - Val Loss: 11.72200445229335, bn_score Val Accuracy: 0.8943527918781726, cl_score Val Accuracy: 0.05767766497461929
# Model saved at ./saved_model/review_classifier_epoch_41.pt
# Train Loss 0 : 0.2809823751449585
# Train Loss 500 : 0.33211132723414255
# Train Loss 1000 : 0.3385480101165417
# Train Loss 1500 : 0.3445679916194246
# Train Loss 2000 : 0.35102701121787616
# Train Loss 2500 : 0.35200390322316366
# Train Loss 3000 : 0.35413520473345084
# Train Loss 3500 : 0.3579718721564992
# Epoch 41 - Val Loss: 11.842024270225973, bn_score Val Accuracy: 0.896002538071066, cl_score Val Accuracy: 0.06173857868020305
# Model saved at ./saved_model/review_classifier_epoch_42.pt
# Train Loss 0 : 0.5288176536560059
# Train Loss 500 : 0.33187649434733535
# Train Loss 1000 : 0.33747484954771817
# Train Loss 1500 : 0.345338948924767
# Train Loss 2000 : 0.3495830022336646
# Train Loss 2500 : 0.35618782646787234
# Train Loss 3000 : 0.3561606025853949
# Train Loss 3500 : 0.35969600187265016
# Epoch 42 - Val Loss: 11.623220951513634, bn_score Val Accuracy: 0.896256345177665, cl_score Val Accuracy: 0.06370558375634518
# Model saved at ./saved_model/review_classifier_epoch_43.pt
# Train Loss 0 : 0.4306650459766388
# Train Loss 500 : 0.3253205489746468
# Train Loss 1000 : 0.3398942238373029
# Train Loss 1500 : 0.3429266517221193
# Train Loss 2000 : 0.3457200962599592
# Train Loss 2500 : 0.3493176774881104
# Train Loss 3000 : 0.35429203676439075
# Train Loss 3500 : 0.3560916112761937
# Epoch 43 - Val Loss: 11.772885387374227, bn_score Val Accuracy: 0.8949873096446701, cl_score Val Accuracy: 0.056979695431472084
# Model saved at ./saved_model/review_classifier_epoch_44.pt
# Train Loss 0 : 0.33271411061286926
# Train Loss 500 : 0.3364003414730588
# Train Loss 1000 : 0.3405918699431491
# Train Loss 1500 : 0.3367517311212859
# Train Loss 2000 : 0.3395183972329244
# Train Loss 2500 : 0.3445626145831254
# Train Loss 3000 : 0.3503024003399249
# Train Loss 3500 : 0.35378805027199417
# Epoch 44 - Val Loss: 11.607879019654064, bn_score Val Accuracy: 0.8970812182741117, cl_score Val Accuracy: 0.059263959390862944
# Model saved at ./saved_model/review_classifier_epoch_45.pt
# Train Loss 0 : 0.7205763459205627
# Train Loss 500 : 0.3454105676618403
# Train Loss 1000 : 0.34116958378331286
# Train Loss 1500 : 0.3396645353276836
# Train Loss 2000 : 0.3432693507081118
# Train Loss 2500 : 0.3469243340465318
# Train Loss 3000 : 0.3500381122153626
# Train Loss 3500 : 0.35343416423665325
# Epoch 45 - Val Loss: 11.7049399292735, bn_score Val Accuracy: 0.8956852791878173, cl_score Val Accuracy: 0.058248730964467005
# Model saved at ./saved_model/review_classifier_epoch_46.pt
# Train Loss 0 : 0.1613444685935974
# Train Loss 500 : 0.3218060069960986
# Train Loss 1000 : 0.3305022673649745
# Train Loss 1500 : 0.3341759129475149
# Train Loss 2000 : 0.33749174568681106
# Train Loss 2500 : 0.3419869082664452
# Train Loss 3000 : 0.34543801051890677
# Train Loss 3500 : 0.34816753670309347
# Epoch 46 - Val Loss: 11.828021339664112, bn_score Val Accuracy: 0.8932741116751269, cl_score Val Accuracy: 0.05945431472081218
# Model saved at ./saved_model/review_classifier_epoch_47.pt
# Train Loss 0 : 0.33298125863075256
# Train Loss 500 : 0.3290855956009167
# Train Loss 1000 : 0.325607322926794
# Train Loss 1500 : 0.3307855609087131
# Train Loss 2000 : 0.3329212916926525
# Train Loss 2500 : 0.3391518101873683
# Train Loss 3000 : 0.344205968582215
# Train Loss 3500 : 0.34819556060636836
# Epoch 47 - Val Loss: 11.989191030150254, bn_score Val Accuracy: 0.8930837563451777, cl_score Val Accuracy: 0.06034263959390863
# Model saved at ./saved_model/review_classifier_epoch_48.pt
# Train Loss 0 : 0.2208951711654663
# Train Loss 500 : 0.3147831139063645
# Train Loss 1000 : 0.31882419756480623
# Train Loss 1500 : 0.32877116268010514
# Train Loss 2000 : 0.3320292164466862
# Train Loss 2500 : 0.3367498617929096
# Train Loss 3000 : 0.33915731652029374
# Train Loss 3500 : 0.3417850777712193
# Epoch 48 - Val Loss: 11.76213258468597, bn_score Val Accuracy: 0.8937182741116751, cl_score Val Accuracy: 0.06319796954314721
# Model saved at ./saved_model/review_classifier_epoch_49.pt
# Train Loss 0 : 0.447468638420105
# Train Loss 500 : 0.31848246518693524
# Train Loss 1000 : 0.3235678813577472
# Train Loss 1500 : 0.32823722062013216
# Train Loss 2000 : 0.3336390818523681
# Train Loss 2500 : 0.34092022274069333
# Train Loss 3000 : 0.34400002714103756
# Train Loss 3500 : 0.3455107270781737
# Epoch 49 - Val Loss: 11.878574587994125, bn_score Val Accuracy: 0.8970812182741117, cl_score Val Accuracy: 0.05970812182741117
# Model saved at ./saved_model/review_classifier_epoch_50.pt
# Train Loss 0 : 0.3495427370071411
# Train Loss 500 : 0.3357393522105531
# Train Loss 1000 : 0.3395046639953043
# Train Loss 1500 : 0.33563867262220237
# Train Loss 2000 : 0.3348413553332788
# Train Loss 2500 : 0.3369281093497984
# Train Loss 3000 : 0.33773379575402807
# Train Loss 3500 : 0.34029842723321657
# Epoch 50 - Val Loss: 12.10311087826928, bn_score Val Accuracy: 0.891497461928934, cl_score Val Accuracy: 0.06224619289340102
# Model saved at ./saved_model/review_classifier_epoch_51.pt
# Train Loss 0 : 0.1639348864555359
# Train Loss 500 : 0.3145979221486403
# Train Loss 1000 : 0.32493596751015863
# Train Loss 1500 : 0.3256725082167739
# Train Loss 2000 : 0.3291433917536311
# Train Loss 2500 : 0.33373031899651756
# Train Loss 3000 : 0.3354352929277773
# Train Loss 3500 : 0.33759802456607874
# Epoch 51 - Val Loss: 12.412849370171042, bn_score Val Accuracy: 0.8934010152284264, cl_score Val Accuracy: 0.061104060913705585
# Model saved at ./saved_model/review_classifier_epoch_52.pt
# Train Loss 0 : 0.6380195617675781
# Train Loss 500 : 0.3069235146818999
# Train Loss 1000 : 0.315802358872407
# Train Loss 1500 : 0.31890834791016215
# Train Loss 2000 : 0.3256197805771942
# Train Loss 2500 : 0.32975830982585563
# Train Loss 3000 : 0.33481871116483103
# Train Loss 3500 : 0.3360995898718614
# Epoch 52 - Val Loss: 12.321100745675047, bn_score Val Accuracy: 0.894733502538071, cl_score Val Accuracy: 0.05843908629441624
# Model saved at ./saved_model/review_classifier_epoch_53.pt
# Train Loss 0 : 0.2391422986984253
# Train Loss 500 : 0.3256669027541212
# Train Loss 1000 : 0.3231420543018755
# Train Loss 1500 : 0.3269673630639881
# Train Loss 2000 : 0.33169383980866257
# Train Loss 2500 : 0.33105985288311246
# Train Loss 3000 : 0.33335742925662115
# Train Loss 3500 : 0.3352111161044583
# Epoch 53 - Val Loss: 12.494436562907623, bn_score Val Accuracy: 0.894733502538071, cl_score Val Accuracy: 0.054949238578680205
# Model saved at ./saved_model/review_classifier_epoch_54.pt
# Train Loss 0 : 0.5757107734680176
# Train Loss 500 : 0.30934199854776173
# Train Loss 1000 : 0.31143586221081276
# Train Loss 1500 : 0.3178252295195699
# Train Loss 2000 : 0.3250061758960979
# Train Loss 2500 : 0.3298524991794974
# Train Loss 3000 : 0.33282463841937215
# Train Loss 3500 : 0.3371591941756509
# Epoch 54 - Val Loss: 12.229797622494958, bn_score Val Accuracy: 0.891751269035533, cl_score Val Accuracy: 0.06434010152284264
# Model saved at ./saved_model/review_classifier_epoch_55.pt
# Train Loss 0 : 0.15676748752593994
# Train Loss 500 : 0.31398793243749173
# Train Loss 1000 : 0.31788422775033354
# Train Loss 1500 : 0.3228791016318415
# Train Loss 2000 : 0.3252588484263134
# Train Loss 2500 : 0.32656380437204285
# Train Loss 3000 : 0.3284226249517381
# Train Loss 3500 : 0.33096664940304704
# Epoch 55 - Val Loss: 12.898996436329933, bn_score Val Accuracy: 0.8932741116751269, cl_score Val Accuracy: 0.056979695431472084
# Model saved at ./saved_model/review_classifier_epoch_56.pt
# Train Loss 0 : 0.18818160891532898
# Train Loss 500 : 0.31448395439087157
# Train Loss 1000 : 0.31572153227409344
# Train Loss 1500 : 0.3167972006933698
# Train Loss 2000 : 0.3226614473373636
# Train Loss 2500 : 0.32433306270452894
# Train Loss 3000 : 0.3281211215060518
# Train Loss 3500 : 0.3311842386955297
# Epoch 56 - Val Loss: 12.206445525674258, bn_score Val Accuracy: 0.8942893401015228, cl_score Val Accuracy: 0.061040609137055835
# Model saved at ./saved_model/review_classifier_epoch_57.pt
# Train Loss 0 : 0.35075831413269043
# Train Loss 500 : 0.3010890896649596
# Train Loss 1000 : 0.3120371481156224
# Train Loss 1500 : 0.3190175751639874
# Train Loss 2000 : 0.32396787005676325
# Train Loss 2500 : 0.3272054884932795
# Train Loss 3000 : 0.3300498369193621
# Train Loss 3500 : 0.33393724269630803
# Epoch 57 - Val Loss: 12.44876534169876, bn_score Val Accuracy: 0.8934644670050761, cl_score Val Accuracy: 0.061357868020304566
# Model saved at ./saved_model/review_classifier_epoch_58.pt
# Train Loss 0 : 0.5990113019943237
# Train Loss 500 : 0.3052924292946528
# Train Loss 1000 : 0.3206966192676471
# Train Loss 1500 : 0.32055764498659406
# Train Loss 2000 : 0.32227934832437555
# Train Loss 2500 : 0.32250714341535275
# Train Loss 3000 : 0.32498916155872487
# Train Loss 3500 : 0.3294740228327691
# Epoch 58 - Val Loss: 12.564907306106289, bn_score Val Accuracy: 0.8956218274111675, cl_score Val Accuracy: 0.061865482233502536
# Model saved at ./saved_model/review_classifier_epoch_59.pt
# Train Loss 0 : 0.27668553590774536
# Train Loss 500 : 0.305819849556167
# Train Loss 1000 : 0.3064468001088985
# Train Loss 1500 : 0.3128769670952506
# Train Loss 2000 : 0.3138293437827295
# Train Loss 2500 : 0.3169439667519309
# Train Loss 3000 : 0.3198161900219759
# Train Loss 3500 : 0.3244171028967944
# Epoch 59 - Val Loss: 12.55681177762169, bn_score Val Accuracy: 0.8944796954314721, cl_score Val Accuracy: 0.06357868020304569
# Model saved at ./saved_model/review_classifier_epoch_60.pt
# Train Loss 0 : 0.2447086125612259
# Train Loss 500 : 0.29699077199170454
# Train Loss 1000 : 0.3066153425079483
# Train Loss 1500 : 0.3123373704838959
# Train Loss 2000 : 0.3150846857516126
# Train Loss 2500 : 0.31817026987600355
# Train Loss 3000 : 0.3213924761614534
# Train Loss 3500 : 0.3258434572889954
# Epoch 60 - Val Loss: 12.670134804553483, bn_score Val Accuracy: 0.8944796954314721, cl_score Val Accuracy: 0.0640228426395939
# Model saved at ./saved_model/review_classifier_epoch_61.pt
# Train Loss 0 : 0.38737067580223083
# Train Loss 500 : 0.30292330361798614
# Train Loss 1000 : 0.30496029200946
# Train Loss 1500 : 0.30541000306372995
# Train Loss 2000 : 0.3122914330698717
# Train Loss 2500 : 0.3181911904706669
# Train Loss 3000 : 0.3227912148290681
# Train Loss 3500 : 0.3232130902925476
# Epoch 61 - Val Loss: 12.596430594732505, bn_score Val Accuracy: 0.8940355329949239, cl_score Val Accuracy: 0.06491116751269035
# Model saved at ./saved_model/review_classifier_epoch_62.pt
# Train Loss 0 : 0.3319065570831299
# Train Loss 500 : 0.30870136617127053
# Train Loss 1000 : 0.30781664796635044
# Train Loss 1500 : 0.30884290881564147
# Train Loss 2000 : 0.31298862623403606
# Train Loss 2500 : 0.31713238004513117
# Train Loss 3000 : 0.3193685708866045
# Train Loss 3500 : 0.3225783159034856
# Epoch 62 - Val Loss: 12.507371919875697, bn_score Val Accuracy: 0.8941624365482234, cl_score Val Accuracy: 0.05888324873096447
# Model saved at ./saved_model/review_classifier_epoch_63.pt
# Train Loss 0 : 0.297631174325943
# Train Loss 500 : 0.3023215196580587
# Train Loss 1000 : 0.3097401878402962
# Train Loss 1500 : 0.3119554099584027
# Train Loss 2000 : 0.31259672262280924
# Train Loss 2500 : 0.31477327758996715
# Train Loss 3000 : 0.31761339281011286
# Train Loss 3500 : 0.32168916276938336
# Epoch 63 - Val Loss: 12.729999225956915, bn_score Val Accuracy: 0.8922588832487309, cl_score Val Accuracy: 0.056979695431472084
# Model saved at ./saved_model/review_classifier_epoch_64.pt
# Train Loss 0 : 0.2856350839138031
# Train Loss 500 : 0.30115239852351583
# Train Loss 1000 : 0.31045531397769144
# Train Loss 1500 : 0.3082207721235512
# Train Loss 2000 : 0.312800083315928
# Train Loss 2500 : 0.3136329227996642
# Train Loss 3000 : 0.31545310461771403
# Train Loss 3500 : 0.3181021170692252
# Epoch 64 - Val Loss: 12.777168175269818, bn_score Val Accuracy: 0.8928299492385787, cl_score Val Accuracy: 0.06230964467005076
# Model saved at ./saved_model/review_classifier_epoch_65.pt
# Train Loss 0 : 0.19168239831924438
# Train Loss 500 : 0.3067592814222662
# Train Loss 1000 : 0.3149742485692987
# Train Loss 1500 : 0.3148191323917084
# Train Loss 2000 : 0.3165991302842143
# Train Loss 2500 : 0.3149439998899029
# Train Loss 3000 : 0.3176717637985031
# Train Loss 3500 : 0.3206778999132851
# Epoch 65 - Val Loss: 12.801235341155262, bn_score Val Accuracy: 0.894225888324873, cl_score Val Accuracy: 0.05901015228426396
# Model saved at ./saved_model/review_classifier_epoch_66.pt
# Train Loss 0 : 0.31687361001968384
# Train Loss 500 : 0.3010184624922014
# Train Loss 1000 : 0.30094399963032
# Train Loss 1500 : 0.3024823864255545
# Train Loss 2000 : 0.3075024244105113
# Train Loss 2500 : 0.31285828934227977
# Train Loss 3000 : 0.3175660407320236
# Train Loss 3500 : 0.3175610816513205
# Epoch 66 - Val Loss: 12.804970313762796, bn_score Val Accuracy: 0.8930837563451777, cl_score Val Accuracy: 0.055964467005076145
# Model saved at ./saved_model/review_classifier_epoch_67.pt
# Train Loss 0 : 0.08726168423891068
# Train Loss 500 : 0.2982370385234644
# Train Loss 1000 : 0.3028187967230241
# Train Loss 1500 : 0.3066884970613851
# Train Loss 2000 : 0.3094702502819656
# Train Loss 2500 : 0.3136205764704111
# Train Loss 3000 : 0.31604051407363287
# Train Loss 3500 : 0.31817122935606085
# Epoch 67 - Val Loss: 12.66138075041239, bn_score Val Accuracy: 0.8923223350253807, cl_score Val Accuracy: 0.05850253807106599
# Model saved at ./saved_model/review_classifier_epoch_68.pt
# Train Loss 0 : 0.22889286279678345
# Train Loss 500 : 0.29415734527175297
# Train Loss 1000 : 0.2972281261176972
# Train Loss 1500 : 0.3021898549136958
# Train Loss 2000 : 0.3062737708206641
# Train Loss 2500 : 0.30891732836603186
# Train Loss 3000 : 0.3113795789700375
# Train Loss 3500 : 0.31523569639302923
# Epoch 68 - Val Loss: 12.733158392064711, bn_score Val Accuracy: 0.8926395939086295, cl_score Val Accuracy: 0.05666243654822335
# Model saved at ./saved_model/review_classifier_epoch_69.pt
# Train Loss 0 : 0.1758919358253479
# Train Loss 500 : 0.29811897654896846
# Train Loss 1000 : 0.29905809870512634
# Train Loss 1500 : 0.3024343915822246
# Train Loss 2000 : 0.30642813646971345
# Train Loss 2500 : 0.30851756327706237
# Train Loss 3000 : 0.31105425547012705
# Train Loss 3500 : 0.31440913296759265
# Epoch 69 - Val Loss: 12.667792077480417, bn_score Val Accuracy: 0.89251269035533, cl_score Val Accuracy: 0.057741116751269035
# Model saved at ./saved_model/review_classifier_epoch_70.pt
# Train Loss 0 : 0.35055670142173767
# Train Loss 500 : 0.29823729321137515
# Train Loss 1000 : 0.30356976009354547
# Train Loss 1500 : 0.304752966272412
# Train Loss 2000 : 0.3116974388144497
# Train Loss 2500 : 0.3139597131955962
# Train Loss 3000 : 0.3147764854463328
# Train Loss 3500 : 0.31622648380443524
# Epoch 70 - Val Loss: 12.92886837404108, bn_score Val Accuracy: 0.8933375634517766, cl_score Val Accuracy: 0.06453045685279188
# Model saved at ./saved_model/review_classifier_epoch_71.pt
# Train Loss 0 : 0.3838191628456116
# Train Loss 500 : 0.28674739108842884
# Train Loss 1000 : 0.3008647572479911
# Train Loss 1500 : 0.3040864083712435
# Train Loss 2000 : 0.3079269093110867
# Train Loss 2500 : 0.3104023338094062
# Train Loss 3000 : 0.3118573965747449
# Train Loss 3500 : 0.31469181980070504
# Epoch 71 - Val Loss: 12.80328037289045, bn_score Val Accuracy: 0.8921319796954315, cl_score Val Accuracy: 0.06034263959390863
# Model saved at ./saved_model/review_classifier_epoch_72.pt
# Train Loss 0 : 0.25946661829948425
# Train Loss 500 : 0.28716608338400035
# Train Loss 1000 : 0.29538270860508486
# Train Loss 1500 : 0.3009137351110548
# Train Loss 2000 : 0.3045050720444535
# Train Loss 2500 : 0.3088103238387448
# Train Loss 3000 : 0.30981636286385156
# Train Loss 3500 : 0.3126930645194838
# Epoch 72 - Val Loss: 13.248675396669709, bn_score Val Accuracy: 0.8937182741116751, cl_score Val Accuracy: 0.057233502538071065
# Model saved at ./saved_model/review_classifier_epoch_73.pt
# Train Loss 0 : 0.36563313007354736
# Train Loss 500 : 0.27425892491585124
# Train Loss 1000 : 0.2905532544689043
# Train Loss 1500 : 0.297801436934568
# Train Loss 2000 : 0.3010870275375755
# Train Loss 2500 : 0.30592141530347294
# Train Loss 3000 : 0.31193454667208337
# Train Loss 3500 : 0.31408031445163653
# Epoch 73 - Val Loss: 12.847989069762626, bn_score Val Accuracy: 0.894225888324873, cl_score Val Accuracy: 0.0625
# Model saved at ./saved_model/review_classifier_epoch_74.pt
# Train Loss 0 : 0.23339523375034332
# Train Loss 500 : 0.29766311176017135
# Train Loss 1000 : 0.29734069151761056
# Train Loss 1500 : 0.29923519449709335
# Train Loss 2000 : 0.30345125740737483
# Train Loss 2500 : 0.3068276736378872
# Train Loss 3000 : 0.31064032013157195
# Train Loss 3500 : 0.31123798611842285
# Epoch 74 - Val Loss: 13.16341619607643, bn_score Val Accuracy: 0.8935913705583757, cl_score Val Accuracy: 0.05869289340101523
# Model saved at ./saved_model/review_classifier_epoch_75.pt
# Train Loss 0 : 0.2960478365421295
# Train Loss 500 : 0.2872892174713626
# Train Loss 1000 : 0.2902749990141922
# Train Loss 1500 : 0.29822787469864726
# Train Loss 2000 : 0.29974632243765914
# Train Loss 2500 : 0.30520834452712814
# Train Loss 3000 : 0.3094527258698154
# Train Loss 3500 : 0.313454329444511
# Epoch 75 - Val Loss: 13.488941668496896, bn_score Val Accuracy: 0.8948604060913705, cl_score Val Accuracy: 0.059771573604060914
# Model saved at ./saved_model/review_classifier_epoch_76.pt
# Train Loss 0 : 0.19107969105243683
# Train Loss 500 : 0.2931293345645754
# Train Loss 1000 : 0.2953926431374265
# Train Loss 1500 : 0.2966877268956134
# Train Loss 2000 : 0.3007766115658361
# Train Loss 2500 : 0.30302877814212187
# Train Loss 3000 : 0.3067175044626325
# Train Loss 3500 : 0.31030088039452913
# Epoch 76 - Val Loss: 13.26000719476665, bn_score Val Accuracy: 0.8939086294416244, cl_score Val Accuracy: 0.06078680203045685
# Model saved at ./saved_model/review_classifier_epoch_77.pt
# Train Loss 0 : 0.11312203109264374
# Train Loss 500 : 0.27895345518034614
# Train Loss 1000 : 0.288160396321164
# Train Loss 1500 : 0.2946316556785402
# Train Loss 2000 : 0.30133704393394645
# Train Loss 2500 : 0.3032418300331783
# Train Loss 3000 : 0.308206310202155
# Train Loss 3500 : 0.30909195226627534
# Epoch 77 - Val Loss: 13.44708339195948, bn_score Val Accuracy: 0.8919416243654822, cl_score Val Accuracy: 0.05888324873096447
# Model saved at ./saved_model/review_classifier_epoch_78.pt
# Train Loss 0 : 0.46819496154785156
# Train Loss 500 : 0.2795351175015082
# Train Loss 1000 : 0.28942679199059823
# Train Loss 1500 : 0.29409980414922954
# Train Loss 2000 : 0.2963419029454718
# Train Loss 2500 : 0.29903819746986143
# Train Loss 3000 : 0.3038847567256005
# Train Loss 3500 : 0.3081272434670945
# Epoch 78 - Val Loss: 13.352790116780186, bn_score Val Accuracy: 0.8941624365482234, cl_score Val Accuracy: 0.05913705583756345
# Model saved at ./saved_model/review_classifier_epoch_79.pt
# Train Loss 0 : 0.2269551306962967
# Train Loss 500 : 0.2823075342350853
# Train Loss 1000 : 0.28882983517828403
# Train Loss 1500 : 0.2927960504285698
# Train Loss 2000 : 0.2983829980415442
# Train Loss 2500 : 0.3029642070240316
# Train Loss 3000 : 0.3047833211145245
# Train Loss 3500 : 0.30858510702271713
# Epoch 79 - Val Loss: 13.080927187240631, bn_score Val Accuracy: 0.8929568527918782, cl_score Val Accuracy: 0.05786802030456853
# Model saved at ./saved_model/review_classifier_epoch_80.pt
# Train Loss 0 : 0.14499777555465698
# Train Loss 500 : 0.28875727977551624
# Train Loss 1000 : 0.28903443572464044
# Train Loss 1500 : 0.2955342099556996
# Train Loss 2000 : 0.3016726813376367
# Train Loss 2500 : 0.3058622789020683
# Train Loss 3000 : 0.30855294769479014
# Train Loss 3500 : 0.31048972085671606
# Epoch 80 - Val Loss: 13.010755824268953, bn_score Val Accuracy: 0.8951776649746193, cl_score Val Accuracy: 0.058756345177664974
# Model saved at ./saved_model/review_classifier_epoch_81.pt
# Train Loss 0 : 0.27411213517189026
# Train Loss 500 : 0.2775278797599965
# Train Loss 1000 : 0.2890096426691179
# Train Loss 1500 : 0.2962200221389056
# Train Loss 2000 : 0.29970620149026983
# Train Loss 2500 : 0.3027447253273504
# Train Loss 3000 : 0.30565638605024825
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 main()
#
# Cell In[83], line 87, in main()
#      84 results_df = pd.DataFrame(columns=['Val Loss', 'bn_score Val Accuracy', 'cl_score Val Accuracy'])
#      86 for epoch in range(EPOCHS):
# ---> 87     model_train(classifier, train_loader, cl_criterion, bn_criterion, optimizer, device, INTERVAL)
#      88     model_test(classifier, test_loader, cl_criterion, bn_criterion, device, epoch, results_df)  # DataFrame 전달
#      90     # 모델 저장 (에포크 번호 추가)
#
# Cell In[41], line 12, in model_train(model, datasets, cl_criterion, bn_criterion, optimizer, device, interval)
#       9 bn_labels = labels[:, 1].to(device).float()         # 라벨 2진분류  (float형)
#      11 # Forward pass
# ---> 12 classesd, logits = model(input_ids)
#      14 # Calculate losses
#      15 loss_cl = cl_criterion(classesd, cl_labels)         #
#
# File c:\Users\MSI\anaconda3\envs\TEXT_018_230_38\lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\MSI\anaconda3\envs\TEXT_018_230_38\lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# Cell In[74], line 31, in reviewClassifierModel.forward(self, inputs)
#      29 last_output = output[:, -1, :]
#      30 last_output = self.dropout(last_output)
# ---> 31 classesd = self.classifier1(last_output)
#      32 logits = self.classifier2(last_output)
#      34 # LogSoftmax 적용
#
# File c:\Users\MSI\anaconda3\envs\TEXT_018_230_38\lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\MSI\anaconda3\envs\TEXT_018_230_38\lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\MSI\anaconda3\envs\TEXT_018_230_38\lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
def predict(model, text, tokenizer, num_classes):
    model.eval()
    
    # 1. 입력 텍스트를 토큰화 (Okt 사용)
    tokens = tokenizer.morphs(text)
    print(tokens)
    
    vocab = build_vocab(tokens, 5000, ['<pad>', '<unk>'])
    token_to_id = {token: idx for idx, token in enumerate(vocab)}
    id_to_token = {idx: token for idx, token in enumerate(vocab)}

    # 2. 토큰을 ID로 변환 (예: token_to_id)
    input_ids = [token_to_id.get(token, token_to_id["<unk>"]) for token in tokens]
    
    # 3. 입력 길이에 맞게 패딩
    max_length = 32  # 원하는 최대 길이
    pad_id = token_to_id["<pad>"]
    input_ids = input_ids[:max_length] + [pad_id] * (max_length - len(input_ids))
    
    # 4. 입력 텐서 생성
    input_tensor = torch.tensor([input_ids], dtype=torch.float32)  # 배치 차원 추가 및 float로 변환
    
    # 5. 모델에 입력하여 예측
    with torch.no_grad():
        logits = model(input_tensor)
    
    # 6. 소프트맥스 함수로 확률 계산
    probs = torch.softmax(logits, dim=1)
    print(probs)
    
    # 7. 최대 확률을 가진 클래스를 예측
    prediction = torch.argmax(probs, dim=1)

    # 8. 예측 결과 출력
    print(f"Predicted label: {prediction.item()}")

# 입력 예시
num_classes = 9  # 예시: 분류할 클래스 수
predict(reviewClassifierModel, "텍스트", tokenizer, num_classes)
# Out:
# ['윈하', '는', '색', '은', '없지만']
# tensor([[0.0043, 0.0855, 0.2323, 0.6315, 0.0043, 0.0016, 0.0016, 0.0016, 0.0016,
#          0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016,
#          0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016,
#          0.0016, 0.0016, 0.0016, 0.0016, 0.0016]])
# Predicted label: 3
