# %% [markdown]
# [Ensemble - RandomForest & ExtraTree]
# - 배깅 방식: 중복 허용, 랜덤 샘플, 동일 모델(Decision Tree)
#     * 대표 알고리즘: RandomForest
# - 페이스트 방식: 중복 X, 랜덤 샘플, 동일 모델(Decision Tree)
#     * 대표 알고리즘: EXtraTree

# %% [markdown]
# [와인 분류]
# - 2개 종류(0 or 1) 분류

# %% [markdown]
# 1) 모듈 로딩 및 데이터 준비

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_file='../data/wine.csv'

# %%
wine_df=pd.read_csv(data_file)

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alcohol  6497 non-null   float64
#  1   sugar    6497 non-null   float64
#  2   pH       6497 non-null   float64
#  3   class    6497 non-null   float64
# dtypes: float64(4)
# memory usage: 203.2 KB

# %%
wine_df.head(3)
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51    0.0
# 1      9.8    2.6  3.20    0.0
# 2      9.8    2.3  3.26    0.0

# %%
wine_df['class'].value_counts()
# Out:
# class
# 1.0    4898
# 0.0    1599
# Name: count, dtype: int64

# %%
wine_df.describe()
# Out:
#            alcohol        sugar           pH        class
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean     10.491801     5.443235     3.218501     0.753886
# std       1.192712     4.757804     0.160787     0.430779
# min       8.000000     0.600000     2.720000     0.000000
# 25%       9.500000     1.800000     3.110000     1.000000
# 50%      10.300000     3.000000     3.210000     1.000000
# 75%      11.300000     8.100000     3.320000     1.000000
# max      14.900000    65.800000     4.010000     1.000000

# %% [markdown]
# 2) 학습 준비

# %%
feature_df=wine_df[wine_df.columns[:-1]]
target_sr=wine_df[wine_df.columns[-1]]

print('[feature_df]',feature_df.shape, '[target_sr]', target_sr.shape)
# Out:
# [feature_df] (6497, 3) [target_sr] (6497,)

# %%
#데이터셋 분리
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(feature_df,target_sr,
                                                random_state=1,
                                                test_size=0.2,
                                                stratify=target_sr)

# %%
print('x_train:', x_train.shape, 'y_train:', y_train.shape)
print('x_test:',x_test.shape, 'y_test:',y_test.shape)
# Out:
# x_train: (5197, 3) y_train: (5197,)
# x_test: (1300, 3) y_test: (1300,)

# %% [markdown]
# 3) 학습 진행
# - 학습 방법: 지도학습 중 분류
# - 알고리즘: Ensemble-bagging(RandomForestClassifier)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#인스턴스 생성
lf_model=RandomForestClassifier(random_state=7, oob_score=True)

#학습 진행
lf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(oob_score=True, random_state=7)

# %%
#모델 파라미터 확인
print('[classes]',lf_model.classes_)
print('[n_classes]',lf_model.n_classes_,'개')
print()
print('[features names]',lf_model.feature_names_in_)
print('[n features in]',lf_model.n_features_in_,'개')
print('[features importance]',lf_model.feature_importances_)
# Out:
# [classes] [0. 1.]
# [n_classes] 2 개
#
# [features names] ['alcohol' 'sugar' 'pH']
# [n features in] 3 개
# [features importance] [0.23572103 0.49995154 0.26432743]

# %%
print('[best estimator]',lf_model.estimator_)

for i in lf_model.estimators_:
    print(i)
# Out:
# [best estimator] DecisionTreeClassifier()
# DecisionTreeClassifier(max_features='sqrt', random_state=327741615)
# DecisionTreeClassifier(max_features='sqrt', random_state=976413892)
# DecisionTreeClassifier(max_features='sqrt', random_state=1202242073)
# DecisionTreeClassifier(max_features='sqrt', random_state=1369975286)
# DecisionTreeClassifier(max_features='sqrt', random_state=1882953283)
# DecisionTreeClassifier(max_features='sqrt', random_state=2053951699)
# DecisionTreeClassifier(max_features='sqrt', random_state=959775639)
# DecisionTreeClassifier(max_features='sqrt', random_state=1956722279)
# DecisionTreeClassifier(max_features='sqrt', random_state=2052949340)
# DecisionTreeClassifier(max_features='sqrt', random_state=1322904761)
# DecisionTreeClassifier(max_features='sqrt', random_state=165338510)
# DecisionTreeClassifier(max_features='sqrt', random_state=1133316631)
# DecisionTreeClassifier(max_features='sqrt', random_state=4812360)
# DecisionTreeClassifier(max_features='sqrt', random_state=372560217)
# DecisionTreeClassifier(max_features='sqrt', random_state=309457262)
# DecisionTreeClassifier(max_features='sqrt', random_state=1801189930)
# DecisionTreeClassifier(max_features='sqrt', random_state=1152936666)
# DecisionTreeClassifier(max_features='sqrt', random_state=68334472)
# DecisionTreeClassifier(max_features='sqrt', random_state=2146978983)
# DecisionTreeClassifier(max_features='sqrt', random_state=119248870)
# DecisionTreeClassifier(max_features='sqrt', random_state=769786948)
# DecisionTreeClassifier(max_features='sqrt', random_state=1583990192)
# DecisionTreeClassifier(max_features='sqrt', random_state=1304549247)
# DecisionTreeClassifier(max_features='sqrt', random_state=1420943751)
# DecisionTreeClassifier(max_features='sqrt', random_state=1636129708)
# DecisionTreeClassifier(max_features='sqrt', random_state=1687674368)
# DecisionTreeClassifier(max_features='sqrt', random_state=283194443)
# DecisionTreeClassifier(max_features='sqrt', random_state=748743479)
# DecisionTreeClassifier(max_features='sqrt', random_state=1237575930)
# DecisionTreeClassifier(max_features='sqrt', random_state=740097030)
# DecisionTreeClassifier(max_features='sqrt', random_state=1759190803)
# DecisionTreeClassifier(max_features='sqrt', random_state=833359292)
# DecisionTreeClassifier(max_features='sqrt', random_state=916483116)
# DecisionTreeClassifier(max_features='sqrt', random_state=1485942463)
# DecisionTreeClassifier(max_features='sqrt', random_state=1941857605)
# DecisionTreeClassifier(max_features='sqrt', random_state=1844809528)
# DecisionTreeClassifier(max_features='sqrt', random_state=1852015768)
# DecisionTreeClassifier(max_features='sqrt', random_state=1127788727)
# DecisionTreeClassifier(max_features='sqrt', random_state=106941365)
# DecisionTreeClassifier(max_features='sqrt', random_state=1077017712)
# DecisionTreeClassifier(max_features='sqrt', random_state=431854331)
# DecisionTreeClassifier(max_features='sqrt', random_state=1094761661)
# DecisionTreeClassifier(max_features='sqrt', random_state=1933291456)
# DecisionTreeClassifier(max_features='sqrt', random_state=1508798754)
# DecisionTreeClassifier(max_features='sqrt', random_state=989143352)
# DecisionTreeClassifier(max_features='sqrt', random_state=747550921)
# DecisionTreeClassifier(max_features='sqrt', random_state=208262606)
# DecisionTreeClassifier(max_features='sqrt', random_state=1248819750)
# DecisionTreeClassifier(max_features='sqrt', random_state=1757192964)
# DecisionTreeClassifier(max_features='sqrt', random_state=1879603694)
# DecisionTreeClassifier(max_features='sqrt', random_state=571958409)
# DecisionTreeClassifier(max_features='sqrt', random_state=1927692119)
# DecisionTreeClassifier(max_features='sqrt', random_state=100556259)
# DecisionTreeClassifier(max_features='sqrt', random_state=1652057283)
# DecisionTreeClassifier(max_features='sqrt', random_state=1075502152)
# DecisionTreeClassifier(max_features='sqrt', random_state=1535344467)
# DecisionTreeClassifier(max_features='sqrt', random_state=725906352)
# DecisionTreeClassifier(max_features='sqrt', random_state=830456065)
# DecisionTreeClassifier(max_features='sqrt', random_state=2008983232)
# DecisionTreeClassifier(max_features='sqrt', random_state=431532432)
# DecisionTreeClassifier(max_features='sqrt', random_state=879820150)
# DecisionTreeClassifier(max_features='sqrt', random_state=2072909727)
# DecisionTreeClassifier(max_features='sqrt', random_state=2107823453)
# DecisionTreeClassifier(max_features='sqrt', random_state=488352684)
# DecisionTreeClassifier(max_features='sqrt', random_state=1599380060)
# DecisionTreeClassifier(max_features='sqrt', random_state=1938096892)
# DecisionTreeClassifier(max_features='sqrt', random_state=2050422343)
# DecisionTreeClassifier(max_features='sqrt', random_state=1497897239)
# DecisionTreeClassifier(max_features='sqrt', random_state=1571487242)
# DecisionTreeClassifier(max_features='sqrt', random_state=1187621609)
# DecisionTreeClassifier(max_features='sqrt', random_state=1451346723)
# DecisionTreeClassifier(max_features='sqrt', random_state=1917728192)
# DecisionTreeClassifier(max_features='sqrt', random_state=1153832253)
# DecisionTreeClassifier(max_features='sqrt', random_state=1966724487)
# DecisionTreeClassifier(max_features='sqrt', random_state=1348596887)
# DecisionTreeClassifier(max_features='sqrt', random_state=771276892)
# DecisionTreeClassifier(max_features='sqrt', random_state=311923447)
# DecisionTreeClassifier(max_features='sqrt', random_state=612959456)
# DecisionTreeClassifier(max_features='sqrt', random_state=1185621653)
# DecisionTreeClassifier(max_features='sqrt', random_state=358664548)
# DecisionTreeClassifier(max_features='sqrt', random_state=1944945571)
# DecisionTreeClassifier(max_features='sqrt', random_state=202873313)
# DecisionTreeClassifier(max_features='sqrt', random_state=1516030531)
# DecisionTreeClassifier(max_features='sqrt', random_state=1332338555)
# DecisionTreeClassifier(max_features='sqrt', random_state=676025563)
# DecisionTreeClassifier(max_features='sqrt', random_state=1214271969)
# DecisionTreeClassifier(max_features='sqrt', random_state=1590645779)
# DecisionTreeClassifier(max_features='sqrt', random_state=1808153499)
# DecisionTreeClassifier(max_features='sqrt', random_state=1971789316)
# DecisionTreeClassifier(max_features='sqrt', random_state=1861190419)
# DecisionTreeClassifier(max_features='sqrt', random_state=941989921)
# DecisionTreeClassifier(max_features='sqrt', random_state=1798548603)
# DecisionTreeClassifier(max_features='sqrt', random_state=1773786398)
# DecisionTreeClassifier(max_features='sqrt', random_state=2088312505)
# DecisionTreeClassifier(max_features='sqrt', random_state=1745574629)
# DecisionTreeClassifier(max_features='sqrt', random_state=1260873545)
# DecisionTreeClassifier(max_features='sqrt', random_state=775033821)
# DecisionTreeClassifier(max_features='sqrt', random_state=1474484177)
# DecisionTreeClassifier(max_features='sqrt', random_state=1035597695)
# DecisionTreeClassifier(max_features='sqrt', random_state=1289946527)

# %%
print('[sample]', lf_model.estimators_samples_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 print('[sample]', lf_model.estimators_samples_)
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'estimators_samples_'

# %% [markdown]
# 4) 성능 평가

# %%
train_score=lf_model.score(x_train,y_train)
test_score=lf_model.score(x_test,y_test)

# %%
print('[train_score]',train_score)
print('[test_score]',test_score)
# Out:
# [train_score] 0.9973061381566288
# [test_score] 0.9

# %%
print('[lf_model.oob_score_]',lf_model.oob_score_)
# Out:
# [lf_model.oob_score_] 0.89532422551472

# %% [markdown]
# 5) 튜닝
# - RandomizedSearchCV 하이퍼 파라미터 최적화 클래스
#     * 범위가 넓은 하이퍼 파라미터 설정에 좋음
#     * 지정된 범위에서 지정된 횟수만큼 하이퍼 파라미터 추출하여 조합 진행

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
params={'max_depth':range(2,16),
        'min_samples_leaf': range(5,16),
        'criterion':['gini','entropy','log_loss']}

# %%
rf_model=RandomForestClassifier(random_state=7)

# %%
cv=RandomizedSearchCV(rf_model, param_distributions=params,n_iter=50,verbose=4)  #verbose= : 진행단계 보여줌

# %%
cv.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END criterion=log_loss, max_depth=5, min_samples_leaf=13;, score=0.855 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=5, min_samples_leaf=13;, score=0.835 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=5, min_samples_leaf=13;, score=0.862 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=5, min_samples_leaf=13;, score=0.876 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=5, min_samples_leaf=13;, score=0.856 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=13, min_samples_leaf=13;, score=0.872 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=13, min_samples_leaf=13;, score=0.833 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=13, min_samples_leaf=13;, score=0.873 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=13, min_samples_leaf=13;, score=0.881 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=13, min_samples_leaf=13;, score=0.871 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=14, min_samples_leaf=8;, score=0.880 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=14, min_samples_leaf=8;, score=0.840 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=14, min_samples_leaf=8;, score=0.879 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=14, min_samples_leaf=8;, score=0.884 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=14, min_samples_leaf=8;, score=0.872 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=13, min_samples_leaf=15;, score=0.873 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=13, min_samples_leaf=15;, score=0.838 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=13, min_samples_leaf=15;, score=0.876 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=13, min_samples_leaf=15;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=13, min_samples_leaf=15;, score=0.871 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=11, min_samples_leaf=8;, score=0.875 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=11, min_samples_leaf=8;, score=0.839 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=11, min_samples_leaf=8;, score=0.877 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=11, min_samples_leaf=8;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=11, min_samples_leaf=8;, score=0.877 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=7, min_samples_leaf=15;, score=0.869 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=7, min_samples_leaf=15;, score=0.835 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=7, min_samples_leaf=15;, score=0.873 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=7, min_samples_leaf=15;, score=0.884 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=7, min_samples_leaf=15;, score=0.863 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=11, min_samples_leaf=7;, score=0.882 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=11, min_samples_leaf=7;, score=0.844 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=11, min_samples_leaf=7;, score=0.876 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=11, min_samples_leaf=7;, score=0.884 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=11, min_samples_leaf=7;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=14;, score=0.873 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=14;, score=0.838 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=14;, score=0.873 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=14;, score=0.884 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=14;, score=0.871 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=7, min_samples_leaf=11;, score=0.858 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=7, min_samples_leaf=11;, score=0.833 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=7, min_samples_leaf=11;, score=0.877 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=7, min_samples_leaf=11;, score=0.878 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=7, min_samples_leaf=11;, score=0.866 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=3, min_samples_leaf=8;, score=0.800 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=3, min_samples_leaf=8;, score=0.801 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=3, min_samples_leaf=8;, score=0.808 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=3, min_samples_leaf=8;, score=0.833 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=3, min_samples_leaf=8;, score=0.818 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=5, min_samples_leaf=5;, score=0.851 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=5, min_samples_leaf=5;, score=0.842 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=5, min_samples_leaf=5;, score=0.859 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=5, min_samples_leaf=5;, score=0.875 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=5, min_samples_leaf=5;, score=0.865 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=2, min_samples_leaf=13;, score=0.756 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, min_samples_leaf=13;, score=0.767 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, min_samples_leaf=13;, score=0.771 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, min_samples_leaf=13;, score=0.754 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, min_samples_leaf=13;, score=0.754 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=13, min_samples_leaf=6;, score=0.881 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=13, min_samples_leaf=6;, score=0.842 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=13, min_samples_leaf=6;, score=0.882 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=13, min_samples_leaf=6;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=13, min_samples_leaf=6;, score=0.879 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=2, min_samples_leaf=6;, score=0.754 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, min_samples_leaf=6;, score=0.754 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=2, min_samples_leaf=6;, score=0.755 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, min_samples_leaf=6;, score=0.754 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=2, min_samples_leaf=6;, score=0.754 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=15, min_samples_leaf=13;, score=0.875 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=15, min_samples_leaf=13;, score=0.832 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=15, min_samples_leaf=13;, score=0.873 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=15, min_samples_leaf=13;, score=0.879 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=15, min_samples_leaf=13;, score=0.871 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=11, min_samples_leaf=10;, score=0.874 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=11, min_samples_leaf=10;, score=0.839 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=11, min_samples_leaf=10;, score=0.874 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=11, min_samples_leaf=10;, score=0.882 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=11, min_samples_leaf=10;, score=0.868 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=6, min_samples_leaf=13;, score=0.863 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=6, min_samples_leaf=13;, score=0.833 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=6, min_samples_leaf=13;, score=0.870 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=6, min_samples_leaf=13;, score=0.879 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=6, min_samples_leaf=13;, score=0.862 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=3, min_samples_leaf=9;, score=0.805 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, min_samples_leaf=9;, score=0.821 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, min_samples_leaf=9;, score=0.835 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, min_samples_leaf=9;, score=0.841 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=3, min_samples_leaf=9;, score=0.826 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=15, min_samples_leaf=10;, score=0.878 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=15, min_samples_leaf=10;, score=0.837 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=15, min_samples_leaf=10;, score=0.878 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=15, min_samples_leaf=10;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=15, min_samples_leaf=10;, score=0.874 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=5, min_samples_leaf=10;, score=0.853 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=5, min_samples_leaf=10;, score=0.838 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=5, min_samples_leaf=10;, score=0.860 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=5, min_samples_leaf=10;, score=0.877 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=5, min_samples_leaf=10;, score=0.860 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=5, min_samples_leaf=7;, score=0.853 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=5, min_samples_leaf=7;, score=0.839 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=5, min_samples_leaf=7;, score=0.863 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=5, min_samples_leaf=7;, score=0.874 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=5, min_samples_leaf=7;, score=0.859 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=9, min_samples_leaf=15;, score=0.870 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=9, min_samples_leaf=15;, score=0.838 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=9, min_samples_leaf=15;, score=0.877 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=9, min_samples_leaf=15;, score=0.884 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=9, min_samples_leaf=15;, score=0.865 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=7, min_samples_leaf=14;, score=0.862 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=7, min_samples_leaf=14;, score=0.832 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=7, min_samples_leaf=14;, score=0.875 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=7, min_samples_leaf=14;, score=0.878 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=7, min_samples_leaf=14;, score=0.861 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=11, min_samples_leaf=12;, score=0.875 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=11, min_samples_leaf=12;, score=0.836 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=11, min_samples_leaf=12;, score=0.880 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=11, min_samples_leaf=12;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=11, min_samples_leaf=12;, score=0.876 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=3, min_samples_leaf=8;, score=0.805 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, min_samples_leaf=8;, score=0.821 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, min_samples_leaf=8;, score=0.835 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, min_samples_leaf=8;, score=0.843 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=3, min_samples_leaf=8;, score=0.825 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=2, min_samples_leaf=13;, score=0.754 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, min_samples_leaf=13;, score=0.754 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, min_samples_leaf=13;, score=0.755 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=2, min_samples_leaf=13;, score=0.754 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, min_samples_leaf=13;, score=0.754 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=9, min_samples_leaf=14;, score=0.867 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=9, min_samples_leaf=14;, score=0.837 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=9, min_samples_leaf=14;, score=0.875 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=9, min_samples_leaf=14;, score=0.878 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=9, min_samples_leaf=14;, score=0.871 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=5;, score=0.874 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=5;, score=0.846 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=5;, score=0.881 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=5;, score=0.881 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=5;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, min_samples_leaf=8;, score=0.756 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=2, min_samples_leaf=8;, score=0.767 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, min_samples_leaf=8;, score=0.771 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=2, min_samples_leaf=8;, score=0.754 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=2, min_samples_leaf=8;, score=0.754 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=14;, score=0.872 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=14;, score=0.839 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=14;, score=0.874 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=14;, score=0.886 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=14;, score=0.868 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=11, min_samples_leaf=7;, score=0.879 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=11, min_samples_leaf=7;, score=0.838 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=11, min_samples_leaf=7;, score=0.879 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=11, min_samples_leaf=7;, score=0.879 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=11, min_samples_leaf=7;, score=0.869 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=5, min_samples_leaf=6;, score=0.857 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=5, min_samples_leaf=6;, score=0.834 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=5, min_samples_leaf=6;, score=0.868 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=5, min_samples_leaf=6;, score=0.874 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=5, min_samples_leaf=6;, score=0.854 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=10;, score=0.879 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=10;, score=0.840 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=10;, score=0.877 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=10;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=10;, score=0.872 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=3, min_samples_leaf=5;, score=0.798 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=3, min_samples_leaf=5;, score=0.801 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=3, min_samples_leaf=5;, score=0.809 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=3, min_samples_leaf=5;, score=0.835 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=3, min_samples_leaf=5;, score=0.819 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=11, min_samples_leaf=11;, score=0.870 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=11, min_samples_leaf=11;, score=0.838 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=11, min_samples_leaf=11;, score=0.877 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=11, min_samples_leaf=11;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=11, min_samples_leaf=11;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=6, min_samples_leaf=7;, score=0.857 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=6, min_samples_leaf=7;, score=0.832 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=6, min_samples_leaf=7;, score=0.870 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=6, min_samples_leaf=7;, score=0.878 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=6, min_samples_leaf=7;, score=0.863 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=9, min_samples_leaf=10;, score=0.870 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=9, min_samples_leaf=10;, score=0.840 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=9, min_samples_leaf=10;, score=0.868 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=9, min_samples_leaf=10;, score=0.884 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=9, min_samples_leaf=10;, score=0.874 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=13, min_samples_leaf=7;, score=0.877 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=13, min_samples_leaf=7;, score=0.844 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=13, min_samples_leaf=7;, score=0.880 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=13, min_samples_leaf=7;, score=0.882 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=13, min_samples_leaf=7;, score=0.874 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=14, min_samples_leaf=6;, score=0.880 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=14, min_samples_leaf=6;, score=0.841 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=14, min_samples_leaf=6;, score=0.881 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=14, min_samples_leaf=6;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=14, min_samples_leaf=6;, score=0.880 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=10, min_samples_leaf=12;, score=0.869 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=10, min_samples_leaf=12;, score=0.842 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=10, min_samples_leaf=12;, score=0.879 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=10, min_samples_leaf=12;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=10, min_samples_leaf=12;, score=0.872 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, min_samples_leaf=12;, score=0.756 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=2, min_samples_leaf=12;, score=0.767 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=2, min_samples_leaf=12;, score=0.771 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=2, min_samples_leaf=12;, score=0.754 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, min_samples_leaf=12;, score=0.754 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=7, min_samples_leaf=5;, score=0.864 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=7, min_samples_leaf=5;, score=0.838 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=7, min_samples_leaf=5;, score=0.881 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=7, min_samples_leaf=5;, score=0.880 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=7, min_samples_leaf=5;, score=0.867 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=6, min_samples_leaf=8;, score=0.855 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=6, min_samples_leaf=8;, score=0.833 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=6, min_samples_leaf=8;, score=0.871 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=6, min_samples_leaf=8;, score=0.872 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=6, min_samples_leaf=8;, score=0.862 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=14, min_samples_leaf=10;, score=0.877 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=14, min_samples_leaf=10;, score=0.836 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=14, min_samples_leaf=10;, score=0.880 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=14, min_samples_leaf=10;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=14, min_samples_leaf=10;, score=0.880 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=9, min_samples_leaf=8;, score=0.877 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=9, min_samples_leaf=8;, score=0.831 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=9, min_samples_leaf=8;, score=0.881 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=9, min_samples_leaf=8;, score=0.884 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=9, min_samples_leaf=8;, score=0.872 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=6, min_samples_leaf=11;, score=0.862 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=6, min_samples_leaf=11;, score=0.827 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=6, min_samples_leaf=11;, score=0.869 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=6, min_samples_leaf=11;, score=0.873 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=6, min_samples_leaf=11;, score=0.861 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=8, min_samples_leaf=13;, score=0.863 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=8, min_samples_leaf=13;, score=0.839 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=8, min_samples_leaf=13;, score=0.879 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=8, min_samples_leaf=13;, score=0.878 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=8, min_samples_leaf=13;, score=0.870 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=12, min_samples_leaf=9;, score=0.882 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=12, min_samples_leaf=9;, score=0.839 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=12, min_samples_leaf=9;, score=0.880 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=12, min_samples_leaf=9;, score=0.877 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=12, min_samples_leaf=9;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.756 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.767 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.771 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.754 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.754 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=14, min_samples_leaf=15;, score=0.872 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=14, min_samples_leaf=15;, score=0.837 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=14, min_samples_leaf=15;, score=0.872 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=14, min_samples_leaf=15;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=14, min_samples_leaf=15;, score=0.867 total time=   0.2s
# RandomizedSearchCV(estimator=RandomForestClassifier(random_state=7), n_iter=50,
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': range(2, 16),
#                                         'min_samples_leaf': range(5, 16)},
#                    verbose=4)

# %%
print('[cv.best_score]',cv.best_score_)
print('[v.best_params_]',cv.best_params_)
print('[cv.best_estimator_]',cv.best_estimator_)
# Out:
# [cv.best_score] 0.8735855482342488
# [v.best_params_] {'min_samples_leaf': 6, 'max_depth': 13, 'criterion': 'log_loss'}
# [cv.best_estimator_] RandomForestClassifier(criterion='log_loss', max_depth=13, min_samples_leaf=6,
#                        random_state=7)

# %%
cv_result_df=pd.DataFrame(cv.cv_results_)
cv_result_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.183572      0.014854         0.011469        0.000508
# 1        0.236552      0.003153         0.014267        0.000411
# 2        0.267957      0.002913         0.015076        0.000217
# 3        0.237084      0.001520         0.014540        0.000508
# 4        0.259992      0.002642         0.014538        0.000479
# 5        0.217253      0.021484         0.014072        0.000683
# 6        0.268018      0.002321         0.014683        0.000384
# 7        0.235542      0.005104         0.014864        0.000692
# 8        0.217292      0.003360         0.014064        0.000189
# 9        0.148809      0.001846         0.010038        0.000496
# 10       0.188467      0.002612         0.012302        0.000478
# 11       0.133177      0.003695         0.009382        0.000528
# 12       0.288320      0.002504         0.015532        0.000790
# 13       0.137753      0.004829         0.009896        0.000282
# 14       0.243039      0.005133         0.014389        0.000933
# 15       0.263615      0.004754         0.014457        0.000452
# 16       0.207136      0.004728         0.013906        0.000545
# 17       0.156118      0.005622         0.010567        0.000490
# 18       0.270457      0.006895         0.015180        0.000668
# 19       0.191152      0.004829         0.012711        0.001060
# 20       0.195893      0.003434         0.013588        0.000839
# 21       0.243362      0.003799         0.014882        0.000975
# 22       0.226503      0.005389         0.013899        0.001029
# 23       0.253908      0.002443         0.015278        0.000753
# 24       0.151647      0.005098         0.010568        0.000489
# 25       0.139908      0.004962         0.010136        0.000736
# 26       0.237691      0.003483         0.015136        0.000743
# 27       0.292045      0.006386         0.015646        0.000402
# 28       0.137592      0.005606         0.009969        0.000890
# 29       0.253199      0.005799         0.015835        0.000637
# 30       0.275492      0.001553         0.015811        0.000684
# 31       0.189095      0.005962         0.012997        0.000263
# 32       0.265057      0.002721         0.015548        0.000494
# 33       0.157571      0.004488         0.010926        0.000237
# 34       0.266598      0.003007         0.015054        0.000927
# 35       0.213413      0.008491         0.013485        0.000688
# 36       0.258866      0.006290         0.015478        0.000530
# 37       0.278001      0.008948         0.015780        0.000463
# 38       0.297010      0.005864         0.016347        0.000759
# 39       0.259278      0.005190         0.015283        0.000769
# 40       0.139690      0.003582         0.010166        0.000402
# 41       0.238487      0.009293         0.013659        0.000643
# 42       0.207880      0.001507         0.013705        0.000619
# 43       0.282425      0.003232         0.016126        0.000849
# 44       0.260139      0.003917         0.015448        0.000637
# 45       0.217876      0.003453         0.013772        0.001430
# 46       0.233877      0.005918         0.015753        0.000744
# 47       0.271532      0.008412         0.016408        0.000405
# 48       0.140814      0.002545         0.010111        0.000203
# 49       0.256658      0.004365         0.014366        0.000862
#
#    param_min_samples_leaf param_max_depth param_criterion  \
# 0                      13               5        log_loss
# 1                      13              13            gini
# 2                       8              14        log_loss
# 3                      15              13        log_loss
# 4                       8              11        log_loss
# 5                      15               7            gini
# 6                       7              11         entropy
# 7                      14               9         entropy
# 8                      11               7         entropy
# 9                       8               3         entropy
# 10                      5               5        log_loss
# 11                     13               2            gini
# 12                      6              13        log_loss
# 13                      6               2         entropy
# 14                     13              15            gini
# 15                     10              11        log_loss
# 16                     13               6        log_loss
# 17                      9               3            gini
# 18                     10              15         entropy
# 19                     10               5        log_loss
# 20                      7               5        log_loss
# 21                     15               9        log_loss
# 22                     14               7        log_loss
# 23                     12              11            gini
# 24                      8               3            gini
# 25                     13               2         entropy
# 26                     14               9            gini
# 27                      5              10         entropy
# 28                      8               2            gini
# 29                     14              10         entropy
# 30                      7              11            gini
# 31                      6               5            gini
# 32                     10              10         entropy
# 33                      5               3        log_loss
# 34                     11              11         entropy
# 35                      7               6        log_loss
# 36                     10               9        log_loss
# 37                      7              13            gini
# 38                      6              14         entropy
# 39                     12              10        log_loss
# 40                     12               2            gini
# 41                      5               7        log_loss
# 42                      8               6         entropy
# 43                     10              14         entropy
# 44                      8               9            gini
# 45                     11               6         entropy
# 46                     13               8            gini
# 47                      9              12            gini
# 48                     10               2            gini
# 49                     15              14        log_loss
#
#                                                params  split0_test_score  \
# 0   {'min_samples_leaf': 13, 'max_depth': 5, 'crit...           0.854808
# 1   {'min_samples_leaf': 13, 'max_depth': 13, 'cri...           0.872115
# 2   {'min_samples_leaf': 8, 'max_depth': 14, 'crit...           0.879808
# 3   {'min_samples_leaf': 15, 'max_depth': 13, 'cri...           0.873077
# 4   {'min_samples_leaf': 8, 'max_depth': 11, 'crit...           0.875000
# 5   {'min_samples_leaf': 15, 'max_depth': 7, 'crit...           0.869231
# 6   {'min_samples_leaf': 7, 'max_depth': 11, 'crit...           0.881731
# 7   {'min_samples_leaf': 14, 'max_depth': 9, 'crit...           0.873077
# 8   {'min_samples_leaf': 11, 'max_depth': 7, 'crit...           0.857692
# 9   {'min_samples_leaf': 8, 'max_depth': 3, 'crite...           0.800000
# 10  {'min_samples_leaf': 5, 'max_depth': 5, 'crite...           0.850962
# 11  {'min_samples_leaf': 13, 'max_depth': 2, 'crit...           0.755769
# 12  {'min_samples_leaf': 6, 'max_depth': 13, 'crit...           0.880769
# 13  {'min_samples_leaf': 6, 'max_depth': 2, 'crite...           0.753846
# 14  {'min_samples_leaf': 13, 'max_depth': 15, 'cri...           0.875000
# 15  {'min_samples_leaf': 10, 'max_depth': 11, 'cri...           0.874038
# 16  {'min_samples_leaf': 13, 'max_depth': 6, 'crit...           0.863462
# 17  {'min_samples_leaf': 9, 'max_depth': 3, 'crite...           0.804808
# 18  {'min_samples_leaf': 10, 'max_depth': 15, 'cri...           0.877885
# 19  {'min_samples_leaf': 10, 'max_depth': 5, 'crit...           0.852885
# 20  {'min_samples_leaf': 7, 'max_depth': 5, 'crite...           0.852885
# 21  {'min_samples_leaf': 15, 'max_depth': 9, 'crit...           0.870192
# 22  {'min_samples_leaf': 14, 'max_depth': 7, 'crit...           0.861538
# 23  {'min_samples_leaf': 12, 'max_depth': 11, 'cri...           0.875000
# 24  {'min_samples_leaf': 8, 'max_depth': 3, 'crite...           0.804808
# 25  {'min_samples_leaf': 13, 'max_depth': 2, 'crit...           0.753846
# 26  {'min_samples_leaf': 14, 'max_depth': 9, 'crit...           0.867308
# 27  {'min_samples_leaf': 5, 'max_depth': 10, 'crit...           0.874038
# 28  {'min_samples_leaf': 8, 'max_depth': 2, 'crite...           0.755769
# 29  {'min_samples_leaf': 14, 'max_depth': 10, 'cri...           0.872115
# 30  {'min_samples_leaf': 7, 'max_depth': 11, 'crit...           0.878846
# 31  {'min_samples_leaf': 6, 'max_depth': 5, 'crite...           0.856731
# 32  {'min_samples_leaf': 10, 'max_depth': 10, 'cri...           0.878846
# 33  {'min_samples_leaf': 5, 'max_depth': 3, 'crite...           0.798077
# 34  {'min_samples_leaf': 11, 'max_depth': 11, 'cri...           0.870192
# 35  {'min_samples_leaf': 7, 'max_depth': 6, 'crite...           0.856731
# 36  {'min_samples_leaf': 10, 'max_depth': 9, 'crit...           0.870192
# 37  {'min_samples_leaf': 7, 'max_depth': 13, 'crit...           0.876923
# 38  {'min_samples_leaf': 6, 'max_depth': 14, 'crit...           0.879808
# 39  {'min_samples_leaf': 12, 'max_depth': 10, 'cri...           0.869231
# 40  {'min_samples_leaf': 12, 'max_depth': 2, 'crit...           0.755769
# 41  {'min_samples_leaf': 5, 'max_depth': 7, 'crite...           0.864423
# 42  {'min_samples_leaf': 8, 'max_depth': 6, 'crite...           0.854808
# 43  {'min_samples_leaf': 10, 'max_depth': 14, 'cri...           0.876923
# 44  {'min_samples_leaf': 8, 'max_depth': 9, 'crite...           0.876923
# 45  {'min_samples_leaf': 11, 'max_depth': 6, 'crit...           0.861538
# 46  {'min_samples_leaf': 13, 'max_depth': 8, 'crit...           0.862500
# 47  {'min_samples_leaf': 9, 'max_depth': 12, 'crit...           0.881731
# 48  {'min_samples_leaf': 10, 'max_depth': 2, 'crit...           0.755769
# 49  {'min_samples_leaf': 15, 'max_depth': 14, 'cri...           0.872115
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.834615           0.862368           0.875842
# 1            0.832692           0.872955           0.880654
# 2            0.840385           0.878730           0.883542
# 3            0.838462           0.875842           0.884504
# 4            0.839423           0.876805           0.885467
# 5            0.834615           0.872955           0.883542
# 6            0.844231           0.875842           0.883542
# 7            0.838462           0.872955           0.883542
# 8            0.832692           0.876805           0.877767
# 9            0.800962           0.807507           0.833494
# 10           0.842308           0.858518           0.874880
# 11           0.767308           0.770934           0.753609
# 12           0.842308           0.881617           0.884504
# 13           0.753846           0.754572           0.753609
# 14           0.831731           0.872955           0.878730
# 15           0.839423           0.873917           0.881617
# 16           0.832692           0.870067           0.878730
# 17           0.821154           0.835419           0.841193
# 18           0.836538           0.877767           0.885467
# 19           0.837500           0.860443           0.876805
# 20           0.839423           0.863330           0.873917
# 21           0.838462           0.876805           0.883542
# 22           0.831731           0.874880           0.877767
# 23           0.835577           0.879692           0.884504
# 24           0.821154           0.835419           0.843118
# 25           0.753846           0.754572           0.753609
# 26           0.836538           0.874880           0.877767
# 27           0.846154           0.880654           0.880654
# 28           0.767308           0.770934           0.753609
# 29           0.839423           0.873917           0.886429
# 30           0.837500           0.878730           0.878730
# 31           0.833654           0.868142           0.873917
# 32           0.840385           0.876805           0.885467
# 33           0.800962           0.809432           0.835419
# 34           0.838462           0.876805           0.885467
# 35           0.831731           0.870067           0.877767
# 36           0.840385           0.868142           0.883542
# 37           0.844231           0.879692           0.881617
# 38           0.841346           0.880654           0.885467
# 39           0.842308           0.878730           0.885467
# 40           0.767308           0.770934           0.753609
# 41           0.837500           0.880654           0.879692
# 42           0.832692           0.871030           0.871992
# 43           0.835577           0.879692           0.885467
# 44           0.830769           0.880654           0.883542
# 45           0.826923           0.869105           0.872955
# 46           0.839423           0.878730           0.877767
# 47           0.839423           0.879692           0.876805
# 48           0.767308           0.770934           0.753609
# 49           0.836538           0.871992           0.884504
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.855630         0.856653        0.013349               40
# 1            0.871030         0.865889        0.016942               25
# 2            0.871992         0.870891        0.015703                7
# 3            0.871030         0.868583        0.015746               16
# 4            0.876805         0.870700        0.016058                8
# 5            0.863330         0.864735        0.016436               29
# 6            0.874880         0.872045        0.014297                3
# 7            0.871030         0.867813        0.015319               19
# 8            0.866218         0.862235        0.016509               30
# 9            0.818094         0.812011        0.012531               44
# 10           0.865255         0.858384        0.011251               36
# 11           0.753609         0.760246        0.007379               45
# 12           0.878730         0.873586        0.015749                1
# 13           0.753609         0.753896        0.000354               49
# 14           0.871030         0.865889        0.017269               26
# 15           0.868142         0.867428        0.014642               20
# 16           0.862368         0.861464        0.015522               32
# 17           0.825794         0.825674        0.012583               42
# 18           0.873917         0.870315        0.017299               11
# 19           0.860443         0.857615        0.012738               38
# 20           0.859480         0.857807        0.011446               37
# 21           0.865255         0.866851        0.015475               22
# 22           0.861405         0.861464        0.016309               31
# 23           0.875842         0.870123        0.017597               12
# 24           0.824832         0.825866        0.013081               41
# 25           0.753609         0.753896        0.000354               49
# 26           0.871030         0.865505        0.014907               28
# 27           0.874880         0.871276        0.012866                5
# 28           0.753609         0.760246        0.007379               45
# 29           0.868142         0.868005        0.015545               18
# 30           0.869105         0.868582        0.015985               17
# 31           0.853705         0.857230        0.013900               39
# 32           0.871992         0.870699        0.015763                9
# 33           0.819057         0.812589        0.013556               43
# 34           0.874880         0.869161        0.016128               14
# 35           0.863330         0.859925        0.015735               33
# 36           0.873917         0.867236        0.014430               21
# 37           0.873917         0.871276        0.013770                6
# 38           0.879692         0.873393        0.016164                2
# 39           0.871992         0.869545        0.014736               13
# 40           0.753609         0.760246        0.007379               45
# 41           0.867180         0.865890        0.015610               24
# 42           0.862368         0.858578        0.014378               34
# 43           0.879692         0.871470        0.018161                4
# 44           0.871992         0.868776        0.019393               15
# 45           0.861405         0.858385        0.016347               35
# 46           0.870067         0.865697        0.014389               27
# 47           0.874880         0.870506        0.015718               10
# 48           0.753609         0.760246        0.007379               45
# 49           0.867180         0.866466        0.016025               23
