# %%
#모듈 로딩
# Model 관련
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset,DataLoader
import torch.optim as optim
from sklearn.metrics import accuracy_score, f1_score
import torch.optim.lr_scheduler as lr_scheduler


# Data 및 시각화 관련
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import *
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
DEVICE
# Out:
# 'cpu'

# %%
class MyDataset(Dataset):
    def __init__(self, features, targets):
        self.features = features
        self.targets = targets

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return self.features[idx], self.targets[idx]

# %%
class MLPModel(nn.Module):
    def __init__(self, input_size, hidden_sizes, output_size):
        super(MLPModel, self).__init__()

        # 은닉층들을 nn.ModuleList로 관리
        layers = []
        in_features = input_size

        for hidden_size in hidden_sizes:
            layers.append(nn.Linear(in_features, hidden_size))
            layers.append(nn.ReLU())  # 활성화 함수로 ReLU 추가
            in_features = hidden_size  # 다음 레이어의 입력 크기는 현재 레이어의 출력 크기

        # Dropout과 마지막 출력층 추가
        layers.append(nn.Dropout(0.3))  # Dropout 추가
        layers.append(nn.Linear(in_features, output_size))

        self.network = nn.Sequential(*layers)  # Sequential로 레이어 묶음

    def forward(self, x):
        return self.network(x)

# %%
mbti_df=pd.read_csv('../data/MBTI.csv')
mbti_df
# Out:
#                                                     posts  type
# 0       know intj tool use interaction people excuse a...  INTJ
# 1       rap music ehh opp yeah know valid well know fa...  INTJ
# 2       preferably p hd low except wew lad video p min...  INTJ
# 3       drink like wish could drink red wine give head...  INTJ
# 4       space program ah bad deal meing freelance max ...  INTJ
# ...                                                   ...   ...
# 106062  stay frustrate world life want take long nap w...  INFP
# 106063  fizzle around time mention sure mistake thing ...  INFP
# 106064  schedule modify hey w intp strong wing underst...  INFP
# 106065  enfj since january busy schedule able spend li...  INFP
# 106066  feel like men good problem tell parent want te...  INFP
#
# [106067 rows x 2 columns]

# %%
mbti_df['type'].value_counts()
# Out:
# type
# INTP    24961
# INTJ    22427
# INFJ    14963
# INFP    12134
# ENTP    11725
# ENFP     6167
# ISTP     3424
# ENTJ     2955
# ESTP     1986
# ENFJ     1534
# ISTJ     1243
# ISFP      875
# ISFJ      650
# ESTJ      482
# ESFP      360
# ESFJ      181
# Name: count, dtype: int64

# %%
mbti_df['ei_type']=mbti_df['type'].apply(lambda x: 1 if 'I' in str(x) else 0)  # 'I'면 1, 'E'면 0
mbti_df
# Out:
#                                                     posts  type  ei_type
# 0       know intj tool use interaction people excuse a...  INTJ        1
# 1       rap music ehh opp yeah know valid well know fa...  INTJ        1
# 2       preferably p hd low except wew lad video p min...  INTJ        1
# 3       drink like wish could drink red wine give head...  INTJ        1
# 4       space program ah bad deal meing freelance max ...  INTJ        1
# ...                                                   ...   ...      ...
# 106062  stay frustrate world life want take long nap w...  INFP        1
# 106063  fizzle around time mention sure mistake thing ...  INFP        1
# 106064  schedule modify hey w intp strong wing underst...  INFP        1
# 106065  enfj since january busy schedule able spend li...  INFP        1
# 106066  feel like men good problem tell parent want te...  INFP        1
#
# [106067 rows x 3 columns]

# %%
r_sampled_df = mbti_df.groupby('type', group_keys=False).apply(lambda x: x.sample(n=181, random_state=42))
r_sampled_df['type'].value_counts()
# Out:
# type
# ENFJ    181
# ENFP    181
# ENTJ    181
# ENTP    181
# ESFJ    181
# ESFP    181
# ESTJ    181
# ESTP    181
# INFJ    181
# INFP    181
# INTJ    181
# INTP    181
# ISFJ    181
# ISFP    181
# ISTJ    181
# ISTP    181
# Name: count, dtype: int64

# %%
result = pd.DataFrame(columns=['posts','ei_type'] )
for index, row in r_sampled_df.iterrows():
    # 각 행의 단어를 분리
    features = row['posts'].split()
    # 해당 단어에 맞는 타겟 값 생성
    targets = [row['ei_type']] * len(features)

    # 결과 데이터프레임에 추가
    dfs = pd.DataFrame({'posts' : features, 'ei_type':targets})
    result = pd.concat([result, dfs], ignore_index=True)

# %%
r_sampled_df['ei_type'] = r_sampled_df['type'].apply(lambda x: 1 if 'E' in x else 0)

# %%
feature=r_sampled_df['posts'].values
target=r_sampled_df['ei_type'].astype('float64').values

# %%
#벡터화
tfidf = TfidfVectorizer(max_features=5000)  # 최대 5000개의 단어만 사용
X = tfidf.fit_transform(feature)

#Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, target, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=42)

#텐서화
X_train_tensor = torch.FloatTensor(X_train.toarray())
X_test_tensor = torch.FloatTensor(X_test.toarray())
y_train_tensor = torch.LongTensor(y_train)
y_test_tensor = torch.LongTensor(y_test)
x_val_tensor = torch.FloatTensor(X_val.toarray()).to(DEVICE)
y_val_tensor = torch.LongTensor(y_val).to(DEVICE)

# %%
## models 폴더 아래 프로젝트 폴더 아래 모델 파일저장
import os

# 저장 경로
SAVE_PATH = './models/mbti/'
# 저장 파일명
SAVE_FILE = 'ei_model_train_wbs.pth'
# 저장 모델구조 및 파라미터 모두 저장
SAVE_MODEL = 'ei_model_all.pth'

if not os.path.exists(SAVE_PATH):
    os.makedirs(SAVE_PATH)

# %%
train_dataset = MyDataset(X_train_tensor, y_train_tensor)
test_dataset = MyDataset(X_test_tensor, y_test_tensor)
val_dataset = MyDataset(x_val_tensor, y_val_tensor)

train_loader = DataLoader(dataset=train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=32, shuffle=False)
val_loader = DataLoader(dataset=val_dataset, batch_size=32, shuffle=False)

# %%
input_size = 5000
hidden_sizes = [1000, 500, 300, 100, 50]
output_size = 1  # 이진 분류

model = MLPModel(input_size, hidden_sizes, output_size)
model.to(DEVICE)

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
scheduler=lr_scheduler.ReduceLROnPlateau(optimizer,mode='max',patience=10,verbose=True)
# Out:
# c:\Users\desktop\anaconda3\envs\TORCH_38\lib\site-packages\torch\optim\lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
print(model)
# Out:
# MLPModel(
#   (network): Sequential(
#     (0): Linear(in_features=5000, out_features=1000, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1000, out_features=500, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=500, out_features=300, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=300, out_features=100, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=100, out_features=50, bias=True)
#     (9): ReLU()
#     (10): Dropout(p=0.3, inplace=False)
#     (11): Linear(in_features=50, out_features=1, bias=True)
#   )
# )

# %%
# 7. 모델 학습
epochs = 100
LOSS_HISTORY, SCORE_HISTORY = [[],[],[]],[[],[],[]]

for epoch in range(epochs):
    model.train()

    epoch_loss = 0
    train_pred = []
    train_true = []

    for features, targets in train_loader:

        optimizer.zero_grad()

        outputs = model(features).view(-1)
        predicted = torch.round(torch.sigmoid(outputs))
        loss = criterion(outputs, targets.float())

        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
        train_pred.extend(predicted.detach().cpu().numpy())
        train_true.extend(targets.detach().cpu().numpy())

    train_f1 = f1_score(train_pred, train_true)
    avg_loss_train = epoch_loss / len(train_loader)
    print(f'Epoch [{epoch+1}/{epochs}]')
    print(f'[TRAIN] Loss: {avg_loss_train:.4f}, F1: {train_f1:.4f}')

    LOSS_HISTORY[0].append(avg_loss_train)
    SCORE_HISTORY[0].append(train_f1)

    #검증
    model.eval()

    v_pred = []
    v_true = []
    v_loss = 0

    with torch.no_grad():
        for features, targets in val_loader:
            outputs = model(features).view(-1)
            predicted = torch.round(torch.sigmoid(outputs))  # 시그모이드 함수로 확률 변환
            v_pred.extend(predicted.cpu().numpy())
            v_true.extend(targets.cpu().numpy())
            loss = criterion(outputs, targets.float())
            v_loss += loss.item()

        val_f1 = f1_score(train_pred, train_true)
        avg_loss_val = epoch_loss / len(train_loader)

        print(f'[VAL] Loss: {avg_loss_val:.4f}, F1: {val_f1:.4f}')

        LOSS_HISTORY[1].append(avg_loss_val)
        SCORE_HISTORY[1].append(val_f1)


    #모델 평가
    model.eval()
    y_pred = []
    y_true = []
    t_loss=0

    with torch.no_grad():
        for features, targets in test_loader:

            outputs = model(features).view(-1)
            predicted = torch.round(torch.sigmoid(outputs))

            y_pred.extend(predicted.cpu().numpy())
            y_true.extend(targets.cpu().numpy())

            loss = criterion(outputs, targets.float())
            t_loss += loss.item()

        test_f1 = f1_score(y_true, y_pred)
        avg_loss_test = epoch_loss / len(test_loader)

        print(f'[TEST] Loss: {avg_loss_test:.4f}, F1: {test_f1:.4f}')

        LOSS_HISTORY[2].append(avg_loss_test)
        SCORE_HISTORY[2].append(test_f1)

    # 성능 지표 계산
    accuracy = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)

    print(f'Accuracy: {accuracy:.4f}')
    print(f'F1 Score: {f1:.4f}')
    print()

    #최적화 스케줄러 인스턴스 업데이트
    scheduler.step(loss)
    print()
    print(f'scheduler.num_bad_epochs: {scheduler.num_bad_epochs}',end=' ')
    print(f'scheduler.patience: {scheduler.patience}')
    print()

    if len(SCORE_HISTORY[1]) == 1:

        # 첫번째라서 무조건 모델 파라미터 저장
        torch.save(model.state_dict(),SAVE_PATH+SAVE_FILE)

        # 모델 전체 저장
        torch.save(model,SAVE_PATH+SAVE_MODEL)

    else:
        if SCORE_HISTORY[1][-1] >= max(SCORE_HISTORY[1]):
            # torch.save(model.state_dict(),f'{SAVE_PATH}{SAVE_FILE}_{epoch}_{LOSS_HISTORY[1][-1]}')
            torch.save(model.state_dict(),SAVE_PATH+SAVE_FILE)
            # 모델 전체 저장
            torch.save(model,SAVE_PATH+SAVE_MODEL)

    #손실 감소(성능 개선) 안 되는 경우 조기 종료
    if scheduler.num_bad_epochs >= scheduler.patience:
        print()
        print(f'{scheduler.patience} EPOCH 성능 개선 없어서 조기 종료')
        break
# Out:
# Epoch [1/100]
# [TRAIN] Loss: 0.6934, F1: 0.0705
# [VAL] Loss: 0.6934, F1: 0.0705
# [TEST] Loss: 2.1167, F1: 0.0000
# Accuracy: 0.5000
# F1 Score: 0.0000
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [2/100]
# [TRAIN] Loss: 0.6858, F1: 0.5100
# [VAL] Loss: 0.6858, F1: 0.5100
# [TEST] Loss: 2.0936, F1: 0.6623
# Accuracy: 0.7310
# F1 Score: 0.6623
#
#
# scheduler.num_bad_epochs: 1 scheduler.patience: 10
#
# Epoch [3/100]
# [TRAIN] Loss: 0.5083, F1: 0.9211
# [VAL] Loss: 0.5083, F1: 0.9211
# [TEST] Loss: 1.5515, F1: 0.7224
# Accuracy: 0.7655
# F1 Score: 0.7224
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [4/100]
# [TRAIN] Loss: 0.0949, F1: 0.9816
# [VAL] Loss: 0.0949, F1: 0.9816
# [TEST] Loss: 0.2896, F1: 0.7713
# Accuracy: 0.7690
# F1 Score: 0.7713
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [5/100]
# [TRAIN] Loss: 0.0185, F1: 0.9984
# [VAL] Loss: 0.0185, F1: 0.9984
# [TEST] Loss: 0.0566, F1: 0.7650
# Accuracy: 0.7500
# F1 Score: 0.7650
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [6/100]
# [TRAIN] Loss: 0.0070, F1: 0.9995
# [VAL] Loss: 0.0070, F1: 0.9995
# [TEST] Loss: 0.0215, F1: 0.7596
# Accuracy: 0.7741
# F1 Score: 0.7596
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [7/100]
# [TRAIN] Loss: 0.0057, F1: 0.9995
# [VAL] Loss: 0.0057, F1: 0.9995
# [TEST] Loss: 0.0175, F1: 0.7582
# Accuracy: 0.7724
# F1 Score: 0.7582
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [8/100]
# [TRAIN] Loss: 0.0038, F1: 0.9995
# [VAL] Loss: 0.0038, F1: 0.9995
# [TEST] Loss: 0.0117, F1: 0.7600
# Accuracy: 0.7724
# F1 Score: 0.7600
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [9/100]
# [TRAIN] Loss: 0.0027, F1: 0.9995
# [VAL] Loss: 0.0027, F1: 0.9995
# [TEST] Loss: 0.0084, F1: 0.7614
# Accuracy: 0.7741
# F1 Score: 0.7614
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [10/100]
# [TRAIN] Loss: 0.0011, F1: 1.0000
# [VAL] Loss: 0.0011, F1: 1.0000
# [TEST] Loss: 0.0033, F1: 0.7644
# Accuracy: 0.7810
# F1 Score: 0.7644
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [11/100]
# [TRAIN] Loss: 0.0008, F1: 1.0000
# [VAL] Loss: 0.0008, F1: 1.0000
# [TEST] Loss: 0.0024, F1: 0.7617
# Accuracy: 0.7724
# F1 Score: 0.7617
#
#
# scheduler.num_bad_epochs: 1 scheduler.patience: 10
#
# Epoch [12/100]
# [TRAIN] Loss: 0.0006, F1: 1.0000
# [VAL] Loss: 0.0006, F1: 1.0000
# [TEST] Loss: 0.0019, F1: 0.7577
# Accuracy: 0.7707
# F1 Score: 0.7577
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [13/100]
# [TRAIN] Loss: 0.0005, F1: 1.0000
# [VAL] Loss: 0.0005, F1: 1.0000
# [TEST] Loss: 0.0017, F1: 0.7586
# Accuracy: 0.7707
# F1 Score: 0.7586
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [14/100]
# [TRAIN] Loss: 0.0005, F1: 1.0000
# [VAL] Loss: 0.0005, F1: 1.0000
# [TEST] Loss: 0.0015, F1: 0.7605
# Accuracy: 0.7741
# F1 Score: 0.7605
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [15/100]
# [TRAIN] Loss: 0.0004, F1: 1.0000
# [VAL] Loss: 0.0004, F1: 1.0000
# [TEST] Loss: 0.0011, F1: 0.7591
# Accuracy: 0.7724
# F1 Score: 0.7591
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [16/100]
# [TRAIN] Loss: 0.0004, F1: 1.0000
# [VAL] Loss: 0.0004, F1: 1.0000
# [TEST] Loss: 0.0011, F1: 0.7591
# Accuracy: 0.7724
# F1 Score: 0.7591
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [17/100]
# [TRAIN] Loss: 0.0003, F1: 1.0000
# [VAL] Loss: 0.0003, F1: 1.0000
# [TEST] Loss: 0.0008, F1: 0.7591
# Accuracy: 0.7724
# F1 Score: 0.7591
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [18/100]
# [TRAIN] Loss: 0.0002, F1: 1.0000
# [VAL] Loss: 0.0002, F1: 1.0000
# [TEST] Loss: 0.0006, F1: 0.7644
# Accuracy: 0.7810
# F1 Score: 0.7644
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [19/100]
# [TRAIN] Loss: 0.0002, F1: 1.0000
# [VAL] Loss: 0.0002, F1: 1.0000
# [TEST] Loss: 0.0007, F1: 0.7559
# Accuracy: 0.7672
# F1 Score: 0.7559
#
#
# scheduler.num_bad_epochs: 1 scheduler.patience: 10
#
# Epoch [20/100]
# [TRAIN] Loss: 0.0001, F1: 1.0000
# [VAL] Loss: 0.0001, F1: 1.0000
# [TEST] Loss: 0.0004, F1: 0.7591
# Accuracy: 0.7724
# F1 Score: 0.7591
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [21/100]
# [TRAIN] Loss: 0.0001, F1: 1.0000
# [VAL] Loss: 0.0001, F1: 1.0000
# [TEST] Loss: 0.0004, F1: 0.7600
# Accuracy: 0.7724
# F1 Score: 0.7600
#
#
# scheduler.num_bad_epochs: 1 scheduler.patience: 10
#
# Epoch [22/100]
# [TRAIN] Loss: 0.0001, F1: 1.0000
# [VAL] Loss: 0.0001, F1: 1.0000
# [TEST] Loss: 0.0003, F1: 0.7605
# Accuracy: 0.7741
# F1 Score: 0.7605
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [23/100]
# [TRAIN] Loss: 0.0001, F1: 1.0000
# [VAL] Loss: 0.0001, F1: 1.0000
# [TEST] Loss: 0.0003, F1: 0.7595
# Accuracy: 0.7707
# F1 Score: 0.7595
#
#
# scheduler.num_bad_epochs: 1 scheduler.patience: 10
#
# Epoch [24/100]
# [TRAIN] Loss: 0.0001, F1: 1.0000
# [VAL] Loss: 0.0001, F1: 1.0000
# [TEST] Loss: 0.0003, F1: 0.7652
# Accuracy: 0.7810
# F1 Score: 0.7652
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [25/100]
# [TRAIN] Loss: 0.0001, F1: 1.0000
# [VAL] Loss: 0.0001, F1: 1.0000
# [TEST] Loss: 0.0003, F1: 0.7572
# Accuracy: 0.7690
# F1 Score: 0.7572
#
#
# scheduler.num_bad_epochs: 1 scheduler.patience: 10
#
# Epoch [26/100]
# [TRAIN] Loss: 0.0001, F1: 1.0000
# [VAL] Loss: 0.0001, F1: 1.0000
# [TEST] Loss: 0.0003, F1: 0.7652
# Accuracy: 0.7810
# F1 Score: 0.7652
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [27/100]
# [TRAIN] Loss: 0.0001, F1: 1.0000
# [VAL] Loss: 0.0001, F1: 1.0000
# [TEST] Loss: 0.0002, F1: 0.7605
# Accuracy: 0.7741
# F1 Score: 0.7605
#
#
# scheduler.num_bad_epochs: 1 scheduler.patience: 10
#
# Epoch [28/100]
# [TRAIN] Loss: 0.0001, F1: 1.0000
# [VAL] Loss: 0.0001, F1: 1.0000
# [TEST] Loss: 0.0002, F1: 0.7645
# Accuracy: 0.7759
# F1 Score: 0.7645
#
#
# scheduler.num_bad_epochs: 2 scheduler.patience: 10
#
# Epoch [29/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7619
# Accuracy: 0.7759
# F1 Score: 0.7619
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [30/100]
# [TRAIN] Loss: 0.0001, F1: 1.0000
# [VAL] Loss: 0.0001, F1: 1.0000
# [TEST] Loss: 0.0002, F1: 0.7644
# Accuracy: 0.7810
# F1 Score: 0.7644
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [31/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7628
# Accuracy: 0.7759
# F1 Score: 0.7628
#
#
# scheduler.num_bad_epochs: 1 scheduler.patience: 10
#
# Epoch [32/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7575
# Accuracy: 0.7759
# F1 Score: 0.7575
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [33/100]
# [TRAIN] Loss: 0.0001, F1: 1.0000
# [VAL] Loss: 0.0001, F1: 1.0000
# [TEST] Loss: 0.0002, F1: 0.7636
# Accuracy: 0.7759
# F1 Score: 0.7636
#
#
# scheduler.num_bad_epochs: 1 scheduler.patience: 10
#
# Epoch [34/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7623
# Accuracy: 0.7741
# F1 Score: 0.7623
#
#
# scheduler.num_bad_epochs: 2 scheduler.patience: 10
#
# Epoch [35/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7614
# Accuracy: 0.7741
# F1 Score: 0.7614
#
#
# scheduler.num_bad_epochs: 3 scheduler.patience: 10
#
# Epoch [36/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7621
# Accuracy: 0.7793
# F1 Score: 0.7621
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [37/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7619
# Accuracy: 0.7759
# F1 Score: 0.7619
#
#
# scheduler.num_bad_epochs: 1 scheduler.patience: 10
#
# Epoch [38/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7607
# Accuracy: 0.7690
# F1 Score: 0.7607
#
#
# scheduler.num_bad_epochs: 2 scheduler.patience: 10
#
# Epoch [39/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7610
# Accuracy: 0.7759
# F1 Score: 0.7610
#
#
# scheduler.num_bad_epochs: 3 scheduler.patience: 10
#
# Epoch [40/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7610
# Accuracy: 0.7759
# F1 Score: 0.7610
#
#
# scheduler.num_bad_epochs: 4 scheduler.patience: 10
#
# Epoch [41/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7575
# Accuracy: 0.7759
# F1 Score: 0.7575
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [42/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7596
# Accuracy: 0.7741
# F1 Score: 0.7596
#
#
# scheduler.num_bad_epochs: 1 scheduler.patience: 10
#
# Epoch [43/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7605
# Accuracy: 0.7741
# F1 Score: 0.7605
#
#
# scheduler.num_bad_epochs: 2 scheduler.patience: 10
#
# Epoch [44/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7591
# Accuracy: 0.7724
# F1 Score: 0.7591
#
#
# scheduler.num_bad_epochs: 3 scheduler.patience: 10
#
# Epoch [45/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7652
# Accuracy: 0.7810
# F1 Score: 0.7652
#
#
# scheduler.num_bad_epochs: 4 scheduler.patience: 10
#
# Epoch [46/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7575
# Accuracy: 0.7759
# F1 Score: 0.7575
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [47/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0000, F1: 0.7630
# Accuracy: 0.7793
# F1 Score: 0.7630
#
#
# scheduler.num_bad_epochs: 1 scheduler.patience: 10
#
# Epoch [48/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0001, F1: 0.7580
# Accuracy: 0.7776
# F1 Score: 0.7580
#
#
# scheduler.num_bad_epochs: 0 scheduler.patience: 10
#
# Epoch [49/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0000, F1: 0.7607
# Accuracy: 0.7776
# F1 Score: 0.7607
#
#
# scheduler.num_bad_epochs: 1 scheduler.patience: 10
#
# Epoch [50/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0000, F1: 0.7630
# Accuracy: 0.7793
# F1 Score: 0.7630
#
#
# scheduler.num_bad_epochs: 2 scheduler.patience: 10
#
# Epoch [51/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0000, F1: 0.7630
# Accuracy: 0.7793
# F1 Score: 0.7630
#
#
# scheduler.num_bad_epochs: 3 scheduler.patience: 10
#
# Epoch [52/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0000, F1: 0.7652
# Accuracy: 0.7810
# F1 Score: 0.7652
#
#
# scheduler.num_bad_epochs: 4 scheduler.patience: 10
#
# Epoch [53/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0000, F1: 0.7645
# Accuracy: 0.7759
# F1 Score: 0.7645
#
#
# scheduler.num_bad_epochs: 5 scheduler.patience: 10
#
# Epoch [54/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0000, F1: 0.7643
# Accuracy: 0.7724
# F1 Score: 0.7643
#
#
# scheduler.num_bad_epochs: 6 scheduler.patience: 10
#
# Epoch [55/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0000, F1: 0.7692
# Accuracy: 0.7828
# F1 Score: 0.7692
#
#
# scheduler.num_bad_epochs: 7 scheduler.patience: 10
#
# Epoch [56/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0000, F1: 0.7630
# Accuracy: 0.7793
# F1 Score: 0.7630
#
#
# scheduler.num_bad_epochs: 8 scheduler.patience: 10
#
# Epoch [57/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0000, F1: 0.7599
# Accuracy: 0.7690
# F1 Score: 0.7599
#
#
# scheduler.num_bad_epochs: 9 scheduler.patience: 10
#
# Epoch [58/100]
# [TRAIN] Loss: 0.0000, F1: 1.0000
# [VAL] Loss: 0.0000, F1: 1.0000
# [TEST] Loss: 0.0000, F1: 0.7650
# Accuracy: 0.7776
# F1 Score: 0.7650
#
#
# scheduler.num_bad_epochs: 10 scheduler.patience: 10
#
#
# 10 EPOCH 성능 개선 없어서 조기 종료

# %%
#학습 결과 확인(학습과 검증의 Loss, 성능지표 변화 확인) w. 시각화

th=len(SCORE_HISTORY[1])
fg,axes=plt.subplots(1,2,figsize=(10,5))
axes[0].plot(range(1,th+1),LOSS_HISTORY[0][:th],label='Train')
axes[0].plot(range(1,th+1),LOSS_HISTORY[1][:th],label='Val')
axes[0].plot(range(1,th+1),LOSS_HISTORY[2][:th],label='Test')
axes[0].set_title('LOSS')
axes[0].grid()
axes[0].legend()

axes[1].plot(range(1,th+1),SCORE_HISTORY[0][:th],label='Train')
axes[1].plot(range(1,th+1),SCORE_HISTORY[1][:th],label='Val')
axes[1].plot(range(1,th+1),SCORE_HISTORY[2][:th],label='Test')
axes[1].set_title('SCORE')
axes[1].grid()
axes[1].legend()

plt.show()
